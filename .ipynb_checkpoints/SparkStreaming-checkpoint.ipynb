# %% [markdown]
# # Preparing the environment

# %% [markdown]
# ## Import dependencies

# %%
#    Spark
from pyspark import SparkContext
#    Spark Streaming
from pyspark.streaming import StreamingContext
#    Kafka
from pyspark.streaming.kafka import KafkaUtils
#    json parsing
import json
#    print function
from __future__ import print_function
#    os
import sys

# %% [markdown]
# ## Create Streaming Context

# %%
zkQuorum = "localhost:2181"
topic = "twitter-stream"
seconds_to_run = 60
ssc = StreamingContext(sc, seconds_to_run)

tweets = KafkaUtils.createStream(ssc, zkQuorum, "spark-streaming-consumer", {topic: 1})

# %% [markdown]
# ## Parse the inbound message as json

# %% [markdown]
# The inbound stream is a DStream, which supports various built-in transformations such as map which is used here to parse the inbound messages from their native JSON format.
# Note that this will fail horribly if the inbound message isn't valid JSON.

# %%
parsed = tweets.map(lambda v: json.loads(v[1]))

# %%
parsed.count().map(lambda x:'Tweets in this batch: %s' % x).pprint()

# %% [markdown]
# ## Extract Text from each tweet

# %%
text_dstream = parsed.map(lambda tweet: tweet['text'])
#text_dstream.pprint()

# %% [markdown]
# ## Process the extracted text

# %%
import nltk
import csv
import string
import re
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# %%
def filter_out_unicode(tweet):
  
    try:
        clean_tweet = str(tweet)
    except UnicodeEncodeError:
        pass
    return clean_tweet

def expand_around_chars(text, characters):
    for char in characters:
        text = text.replace(char, ' ' + char + ' ')
    return text

def strip_quotations_newline(text):
    clean_tweet = ' '.join(text.split())
    clean_tweet = clean_tweet.encode('utf-8')
    clean_tweet = clean_tweet.replace('",\'','')
    clean_tweet = re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', "", clean_tweet)
    clean_tweet = re.sub(r'''(@[A-Za-z0-9]+)''', "", clean_tweet)
    clean_tweet = re.sub("([0-9]+)", "", clean_tweet)
    clean_tweet = re.sub(r'[^\x00-\x7F]+','', clean_tweet)
    return clean_tweet

def split_text(text):
    text = strip_quotations_newline(text)
    text = expand_around_chars(text, '\/".,()&[]{}:;!-_\'')
    splitted_text = text.split(' ')
    cleaned_text = [x for x in splitted_text if len(x) > 2]
    text_lowercase = [x.lower() for x in cleaned_text]
    return text_lowercase

# %%
mess = text_dstream.map(lambda text: ' '.join(split_text(text)))
mess.pprint()

# %% [markdown]
# ## Create clean tweet

# %%
tweet_df = mess.foreachRDD(lambda rdd: rdd.toDF("text"))
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-12-977c4d20cde0> in <module>()
# ----> 1 tweet_df = mess.foreachRDD(lambda rdd: rdd.toDF("text"))
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/streaming/dstream.py in foreachRDD(self, func)
#     160         jfunc = TransformFunction(self._sc, func, self._jrdd_deserializer)
#     161         api = self._ssc._jvm.PythonDStream
# --> 162         api.callForeachRDD(self._jdstream, jfunc)
#     163
#     164     def pprint(self, num=10):
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     317                 raise Py4JJavaError(
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#     321                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.streaming.api.python.PythonDStream.callForeachRDD.
# : java.lang.IllegalStateException: Adding new inputs, transformations, and output operations after starting a context is not supported
# 	at org.apache.spark.streaming.dstream.DStream.validateAtInit(DStream.scala:223)
# 	at org.apache.spark.streaming.dstream.DStream.<init>(DStream.scala:65)
# 	at org.apache.spark.streaming.dstream.ForEachDStream.<init>(ForEachDStream.scala:39)
# 	at org.apache.spark.streaming.dstream.DStream.org$apache$spark$streaming$dstream$DStream$$foreachRDD(DStream.scala:653)
# 	at org.apache.spark.streaming.dstream.DStream$$anonfun$foreachRDD$2.apply$mcV$sp(DStream.scala:638)
# 	at org.apache.spark.streaming.dstream.DStream$$anonfun$foreachRDD$2.apply(DStream.scala:638)
# 	at org.apache.spark.streaming.dstream.DStream$$anonfun$foreachRDD$2.apply(DStream.scala:638)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.SparkContext.withScope(SparkContext.scala:679)
# 	at org.apache.spark.streaming.StreamingContext.withScope(StreamingContext.scala:264)
# 	at org.apache.spark.streaming.dstream.DStream.foreachRDD(DStream.scala:634)
# 	at org.apache.spark.streaming.api.python.PythonDStream$.callForeachRDD(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream.callForeachRDD(PythonDStream.scala)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:237)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:280)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Thread.java:748)
# -------------------------------------------
# Time: 2017-06-20 15:03:00
# -------------------------------------------
# Tweets in this batch: 49

# %%
tweet_df
# Out:
# -------------------------------------------
# Time: 2017-06-20 15:03:00
# -------------------------------------------
# ing doyoung noticed yuta hands shaking out nervousness and held his hands calm his nerves down
# ~lerrrd shaking~ #fightmyway
# last earthquake sat jun gmt location lat long magnitude
# where were they radicalized
# panther whales out here hittin licks seen all
# all the trump kids supposedly went good schools but their grammar bad their father
# imagine this dance king hit the stage already shaking
# the #finsburypark attacker targeted worshippers attempt drive fear failed prayers were held the
# jisoo duality has shaking oml
# nature strikes back
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:04:00
# -------------------------------------------
# Tweets in this batch: 57
#
# -------------------------------------------
# Time: 2017-06-20 15:04:00
# -------------------------------------------
# kim taeyeon she vocal goddess she has such stable vocals shaking she eats cds for every meal
# are the verge massive earthquakeor something much worse? via
# magnitude earthquake occurred nnw saumlaki indonesia details map
# usgs reports #earthquake nnw saumlaki indonesia utc #quake
# friend mine shared his story being the horrific san francisco earthquake
# ara won shaking #whatsmynamestwin
# quake magnitude nnw saumlaki indonesia june gmt
# quake magnitude nnw saumlaki indonesia june
# earthquake nnw saumlaki indonesia epicenter ago depth
#
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:05:00
# -------------------------------------------
# Tweets in this batch: 65
#
# -------------------------------------------
# Time: 2017-06-20 15:05:00
# -------------------------------------------
# soon sooooo son can feel legs shaking
# swimming pool during earthquake
# earthquake nnw saumlaki indonesia epicenter ago depth
# online the evaluation report the post tsunami coastal rehabilitation and resource management program #srilanka
# models are shaking #choicesongmaleartist #teenchoice
# wrong fucking neighborhood
# glad see some activities rehabilitate reconstruct earthquake damaged monuments patan but still much
# ing doyoung noticed yuta hands shaking out nervousness and held his hands calm his nerves down
# jonny amp thom play one off show macerata sferisterio august proceeds will help the restoration earthq
# the vote went the tories
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:06:00
# -------------------------------------------
# Tweets in this batch: 56
#
# -------------------------------------------
# Time: 2017-06-20 15:06:00
# -------------------------------------------
# bad that almost cross about that apostrophe about the rest this tweet?
# panther whales out here hittin licks seen all
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report via
# this whale literally looks like saying run
# earthquake nnw saumlaki indonesia #earthquake #fb
# further concerns about slope instability details amp video #landslide that triggered nuugaatsiaq #tsunami
# panther whales out here hittin licks seen all
# earthquake nnw saumlaki indonesia utc has been changed from magnitude #earthquake
# lmao most advanced predator the planet and not even close
# cnn poll puts for voting fails absolute landslide link vote
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:07:00
# -------------------------------------------
# Tweets in this batch: 78
#
# -------------------------------------------
# Time: 2017-06-20 15:07:00
# -------------------------------------------
# she shaking them titties girl yes
# panther whales out here hittin licks seen all
# jay panorama reported people lived #grenfelltower there are reported survivors yet authorities say only are missi
# visiting here try
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# right there stans loyal love ariana and sean collabs her dress the video romeo and juliet are shaking https
# panther whales out here hittin licks seen all
# tsunami sweeps away homes greenland related articles
# always think coffee good idea drink and then get weird jitters and can stop shaking like maybe not?????
# omar coming
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:08:00
# -------------------------------------------
# Tweets in this batch: 63
#
# -------------------------------------------
# Time: 2017-06-20 15:08:00
# -------------------------------------------
# #nonmuslims break fast with #muslims during relief efforts #grenfelltower #northkensington #grenfell #latimerroad
# whore begins shaking her jugs she gets hammered
# fishermen paying them protection money whale overdue right? riiiiight? *goes for high fives*
# want video footage this whale shaking down the boat
# did love shaking huhuhu thank you and love you soooo much
# stay the fuck outta their hood then
# civilians reported dead after fudged led strike syria reaction far
# she shaking them titties girl yes
# praying she wins landslide
# earthquake nnw saumlaki indonesia epicenter ago depth
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:09:00
# -------------------------------------------
# Tweets in this batch: 63
#
# -------------------------------------------
# Time: 2017-06-20 15:09:00
# -------------------------------------------
# and also wow shook shaking triggered snatched the
# earthquake swarm hits yellowstone super volcano time bomb for north america
# ing doyoung noticed yuta hands shaking out nervousness and held his hands calm his nerves down
# omar coming
# panther whales out here hittin licks seen all
# ara won shaking #whatsmynamestwin
# #trump shaking things complacent and they hate the change keep #trump
# bitch better have fish
# qatar accuses uae supporting attacks new york gulf crisis deepens
# earthquake amp typhoon #hasbros series check amp more amp post your moc loose for
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:10:00
# -------------------------------------------
# Tweets in this batch: 60
#
# -------------------------------------------
# Time: 2017-06-20 15:10:00
# -------------------------------------------
# remember this moment when taehyung was singing you and was pointing jimin the you vmin heart
# jets you ain from hood
# remember this moment when taehyung was singing you and was pointing jimin the you vmin heart
# blood tsunami let blood rain
# panther whales out here hittin licks seen all
# blackpink shaking #krunk
# the vote went the tories
# panther whales out here hittin licks seen all
# models are shaking and dropping their jobs
# have you seen this tropical system the gulf? could become tropicalstormcindy landfall late wednesday near sabin
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:11:00
# -------------------------------------------
# Tweets in this batch: 56
#
# -------------------------------------------
# Time: 2017-06-20 15:11:00
# -------------------------------------------
# models are shaking and dropping their jobs
# earthquake nnw saumlaki indonesia epicenter ago depth
# just earthquake cannot improve city neither are mutations advantageous develop living things
# #animalanarchy soon come
# fuck free willy
# panther whales out here hittin licks seen all
# the modeling industry shaking are actual models
# another sectarian attack london thoughts amp prayers with victims
# stay the fuck outta their hood then
# those are your words never said that april stop shaking your head there now like you been the press briefing
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:12:00
# -------------------------------------------
# Tweets in this batch: 45
#
# -------------------------------------------
# Time: 2017-06-20 15:12:00
# -------------------------------------------
# euiwoong shaking
# aftershocks stories from the japan earthquake our man abiko
# earthquake space? nominate #kindlescout enjoy this #bookbubble
# panther whales out here hittin licks seen all
# red velvet coming back shaking
# earthquake nnw saumlaki indonesia epicenter ago depth
# this rape can take this literally shaking
# one scientists warn current yellowstone quake swarm could rip the guts out america
# this rape can take this literally shaking
# jay panorama reported people lived #grenfelltower there are reported survivors yet authorities say only are missi
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:13:00
# -------------------------------------------
# Tweets in this batch: 50
#
# -------------------------------------------
# Time: 2017-06-20 15:13:00
# -------------------------------------------
# remember this moment when taehyung was singing you and was pointing jimin the you vmin heart
# models are shaking and dropping their jobs
# your legs are shaking afterward you know was good
# joemanchin are you shaking your boots joe?
# where were they radicalized
# busch what wrote good luck everyone #wi
# see nothing wrong here nature fighting back
# the irony burns
# you know given the number times and kidnapped one their friends entertain just saying
# katy perry shaking
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15
aking
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:20:00
# -------------------------------------------
# Tweets in this batch: 47
#
# -------------------------------------------
# Time: 2017-06-20 15:20:00
# -------------------------------------------
# jonny amp thom play one off show macerata sferisterio august proceeds will help the restoration earthq
# was shaking alrd ahsjhaja and you changed handle sis just realized
# the fake left wants overthrow president who won landslide not counting illegal votes install globalist
# panther whales out here hittin licks seen all
# their fish you killer whales
# not good #yellowstone #nationalpark #volcano #supervolcano #earthquake #earthquakes #fact #facts #random #trivia
# veigh the #grenfelltowerappeal help families affected the fire
# morty nor gonna pay for replacement parts it? his tone was now low and threatening
# your legs are shaking afterward you know was good
# ara won shaking #whatsmynamestwin
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:21:00
# -------------------------------------------
# Tweets in this batch: 70
#
# -------------------------------------------
# Time: 2017-06-20 15:21:00
# -------------------------------------------
# models are shaking and dropping their jobs
# drudgereport #update #yellowstone supervolcano hit #quakes week
# #update #yellowstone supervolcano hit #quakes week
# drudgereport #update #yellowstone supervolcano hit #quakes week
# #update #yellowstone supervolcano hit #quakes week
# drudgereport #update #yellowstone supervolcano hit #quakes week
# #update #yellowstone supervolcano hit #quakes week
# bruh have whales out here doing more than most people
# drudgereport #update #yellowstone supervolcano hit #quakes week
# the outer suit beeper our executives are demon and seismic approximately two princesss ago
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:22:00
# -------------------------------------------
# Tweets in this batch: 49
#
# -------------------------------------------
# Time: 2017-06-20 15:22:00
# -------------------------------------------
# another six month wait for november earthquake claimants
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# she shaking them titties girl yes
# panther whales out here hittin licks seen all
# small earthquake rumbles southeast missouri
# jay panorama reported people lived #grenfelltower there are reported survivors yet authorities say only are missi
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# missed the sathan broadcast can someone send moments that they captured
# blackpink shaking #krunk
# landslide win then was tied then she was leading little assoff can even vote for
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:23:00
# -------------------------------------------
# Tweets in this batch: 61
#
# -------------------------------------------
# Time: 2017-06-20 15:23:00
# -------------------------------------------
# magnitude #earthquake from mount hood village #or united states
# maguire may deciding bad deal better than deal with the dup she shaking the magic money tree buy votes many cli
# the whales are fed with our shit
# magnitude quake just north hyden was recorded our jackson station about edt last night
# oooo this bitch shaking the table
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# panther whales out here hittin licks seen all
# maguire may deciding bad deal better than deal with the dup she shaking the magic money tree buy votes many cli
# even your hands are shaking
# models are shaking and dropping their jobs
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:24:00
# -------------------------------------------
# Tweets in this batch: 50
#
# -------------------------------------------
# Time: 2017-06-20 15:24:00
# -------------------------------------------
# civilians reported dead after fudged led strike syria reaction far
# korea china japan conduct joint research quake risks
# stay the fuck outta their hood then
# earthquake detected nnw saumlaki indonesia
# update heart still slightly palpating and legs won stop shaking this why can have nice things
# joyri ended the new notification icon whole twitter shaking
# man this great rantaro touched the offer and does accept his hand firmly shaking
# #earthquake strikes #trkmenbay #turkmenistan min ago more info
# remember this moment when taehyung was singing you and was pointing jimin the you vmin heart
# will having minutes silence this evening have good rehearsal look forward great evening with gre
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:25:00
# -------------------------------------------
# Tweets in this batch: 46
#
# -------------------------------------------
# Time: 2017-06-20 15:25:00
# -------------------------------------------
# rashid plz share widely rss diverted funds from meant for gujarat earthquake relief fund shakha activities
# have you seen this? looks interesting
# did take full day after rains came ashore for katrina make landfall? don recall but guess must hav
# ahyoung walks down the altar with ahyoung hand bit shaking
# idk what shaking miss lalisa booty sexuality??
# ara won shaking #whatsmynamestwin
# just shaking head
# blackpink teaser already has views antis are shaking
# trump landslide electoral votes? history says happening now #presidentelecttrump #maga #privacy
# legal challenge under way
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:26:00
# -------------------------------------------
# Tweets in this batch: 52
#
# -------------------------------------------
# Time: 2017-06-20 15:26:00
# -------------------------------------------
# gonna look cute tomorrow like andy karl will truly shaking his boots
# cnn tries conduct online trump hater poll but turns out landslide support for president
# knows whereof speaks
# panther whales out here hittin licks seen all
# magnitude #earthquake amatignak island alaska
# earthquake nnw saumlaki indonesia time utc
# ing doyoung noticed yuta hands shaking out nervousness and held his hands calm his nerves down
# minki gaga shaking
# why?the groping women and saying some the most outlandish things guess the dems want
# models around the world are shaking the sight these beauts
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:27:00
# -------------------------------------------
# Tweets in this batch: 61
#
# -------------------------------------------
# Time: 2017-06-20 15:27:00
# -------------------------------------------
# ahyoung walks down the altar with ahyoung hand bit shaking
# you probably shake his dick for him
# start where you are start with fear start with pain start with doubt start with hands shaking start and dont
# omg about actually die someone just tried key door shaking omg what do???
# nigga they are called killer whales not cuddly whales not mild mannered whales killer killer motherfuck
# showtek amp justin prime matthew koma cannonball earthquake lyric
# panther whales out here hittin licks seen all
# radioheads and jonny greenwood play rare set duo aid earthquake restoration efforts
# styles shaking see you hamburg #harrystylesliveontour #hamburg #harrystylesgermany
# shaking omg
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:28:00
# -------------------------------------------
# Tweets in this batch: 45
#
# -------------------------------------------
# Time: 2017-06-20 15:28:00
# -------------------------------------------
# ara won shaking #whatsmynamestwin
# opinion the whole cali thing cali wins landslide
# prayers for the victims landslides amp floods sri lanka may god give them strength amp courage face this loss
# radioheads and jonny greenwood play rare set duo aid earthquake restoration efforts
# can handle this like gentleman can get into some gangsta shit
# nuugaatsiaq tsunami details emerge the landslide and new concerns about further potentially unstable slope
# brave freedom fighters are attacking imperialism its core attempting seize the tools their repression
# just sitting desk shaking like salt shaker this air turbo
# ing doyoung noticed yuta hands shaking out nervousness and held his hands calm his nerves down
# biologist squad
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:29:00
# -------------------------------------------
# Tweets in this batch: 51
#
# -------------------------------------------
# Time: 2017-06-20 15:29:00
# -------------------------------------------
# stay the fuck outta their hood then
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# dyanamic close grip bench press with the tsunami bar via
# still crying love the affection between them
# thought passed out because the heat outside but nope was because our queen are back still
# panther whales out here hittin licks seen all
# panther whales out here hittin licks seen all
# vmin being adorable
# models are shaking and dropping their jobs
# you can see but shaking our heads
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:30:00
# -------------------------------------------
# Tweets in this batch: 155
#
# -------------------------------------------
# Time: 2017-06-20 15:30:00
# -------------------------------------------
# the whales are fed with our shit
# #quake andreanof islands aleutian cbfb
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# qatar accuses uae supporting attacks new york gulf crisis deepens
# poor even with millions illegal and deceased votes she still lost??? can any
# mjjeje your head will spinning more than degree coz her slap amp your brain will shake like earthquake
# she shaking them titties girl yes
# nigga they are called killer whales not cuddly whales not mild mannered whales killer killer motherfuck
# maguire may deciding bad deal better than deal with the dup she shaking the magic money tree buy votes many cli
# swore was going sleep then babe pulled with bottle and was harlem shaking and crip walkin smh
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:31:00
# -------------------------------------------
# Tweets in this batch: 49
#
# -------------------------------------------
# Time: 2017-06-20 15:31:00
# -------------------------------------------
# this rape can take this literally shaking
# greenland tsunami four people are missing and nearly dozen homes were flooded after rare #greenland #tsunami
# have you seen this tropical system the gulf? could become #tropicalstormcindy landfall late wednesday near sabin
# our #film opium brides showed tragic effects #poppy eradication years later suffering continues
# where were they radicalized
# theres earthquake happening inside body guest #msconversations
# storm watches amp warnings are effect for louisianas gulf coast the tropical system could make landfall wednesda
# panther whales out here hittin licks seen all
# maguire may deciding bad deal better than deal with the dup she shaking the magic money tree buy votes many cli
aking
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:44:00
# -------------------------------------------
# Tweets in this batch: 60
#
# -------------------------------------------
# Time: 2017-06-20 15:44:00
# -------------------------------------------
# opium use booms afghanistan creating silent tsunami addicted women #afgdrug
# video captures moment when tsunami hits greenland west coast via
# earthquake above point world
# danielle legs wont stop shaking
# shamu fed the fuck
# affect mean from their pov are gangs aggressive humans taking their fish
# geofon program gfz potsdam earthquake bulletin
# the whales are fed with our shit
# earthquake occurred nnw talkeetna alaska utc #earthquake #talkeetna
# this versatility cornell jenner shaking
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:45:00
# -------------------------------------------
# Tweets in this batch: 62
#
# -------------------------------------------
# Time: 2017-06-20 15:45:00
# -------------------------------------------
# #indianarmy rescues lives stranded due landslide near bhalukpong arunachal pradesh #foreverforyou
# imagine this dance king hit the stage already shaking
# niall video him working out the only thing thinking about right now shaking
# panther whales out here hittin licks seen all
# they taking the sea back lol
# jonny amp thom play one off show macerata sferisterio august proceeds will help the restoration earthq
# this whale literally looks like saying run
# qatar accuses uae supporting attacks new york gulf crisis deepens
# data definitive #ge analysis from how youngsters remainers and graduates stole may landslide
# completely fine all over apart from the backs knees which are like tsunami sweat nice image there for you
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:46:00
# -------------------------------------------
# Tweets in this batch: 51
#
# -------------------------------------------
# Time: 2017-06-20 15:46:00
# -------------------------------------------
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# jonny amp thom play one off show macerata sferisterio august proceeds will help the restoration earthq
# panther whales out here hittin licks seen all
# #nowplaying showtek amp justin prime matthew koma cannonball earthquake apricot the home great music
# magnitude #earthquake talkeetna alaska
# smh lawrence gotta shoot him this point
# being fifth year student this the real life? this jusy fantasy? caught landslide escape from reality
# ing doyoung noticed yuta hands shaking out nervousness and held his hands calm his nerves down
# can handle this like gentleman can get into some gangsta shit
# completely fine all over apart from the backs knees which are like tsunami sweat nice image there for you
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:47:00
# -------------------------------------------
# Tweets in this batch: 54
#
# -------------------------------------------
# Time: 2017-06-20 15:47:00
# -------------------------------------------
# ffs give lost that primary landslide both these guys will and men don age well enoug
# this rape can take this literally shaking
# chocolate the answer even saving ecosystem affected climate change how you can help
# our hostel room shaking from club underneath playing shape you loud pls help
# brave freedom fighters are attacking imperialism its core attempting seize the tools their repression
# hoooooo god shaking can have this glo for next time meet her please
# seismic shift underway tech
# wings short films gonna nothing compared what the budget and production value for this going honestly sha
# omg samuel shaking
# stay the fuck outta their hood then
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:48:00
# -------------------------------------------
# Tweets in this batch: 55
#
# -------------------------------------------
# Time: 2017-06-20 15:48:00
# -------------------------------------------
# krystal stares blankly the teacher slowly shaking her head afraid not haven attended any classes
# the modeling industry shaking are actual models
# panther whales out here hittin licks seen all
# the future samuel should have had
# damn what should shaking
# #indianarmy rescues lives stranded due landslide near bhalukpong arunachal pradesh #foreverforyou
# #indianarmy rescues lives stranded due landslide near bhalukpong arunachal pradesh #foreverforyou
# again thoughts and prayers are the victims injured killed #londonmosqueattack place worship place pea
# shaking stop #whatsmynamestwin
# fantastic article there seismic shift opinion towards unity inevitable
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:49:00
# -------------------------------------------
# Tweets in this batch: 54
#
# -------------------------------------------
# Time: 2017-06-20 15:49:00
# -------------------------------------------
# stay the fuck outta their hood then
# stay the fuck outta their hood then
# yellowstone earthquake swarm continues causing panic #eqswarm #yellowstone
# fucking mad shaking anger right now
# totally lost *shaking head
# stay the fuck outta their hood then
# brave freedom fighters are attacking imperialism its core attempting seize the tools their repression
# love listening tsunami with this hot weather
# imagine this dance king hit the stage already shaking
# the modeling industry shaking are actual models
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:50:00
# -------------------------------------------
# Tweets in this batch: 47
#
# -------------------------------------------
# Time: 2017-06-20 15:50:00
# -------------------------------------------
# see the animals are rolling out phase
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# this rape can take this literally shaking
# stay the fuck outta their hood then
# panther whales out here hittin licks seen all
# imagine this dance king hit the stage already shaking
# and your legs start shaking like you having seizure the best
# the modeling industry shaking are actual models
# hard dick booty shaking
# earthquake swarm continues yellowstone quakes hours strange sounds
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:51:00
# -------------------------------------------
# Tweets in this batch: 53
#
# -------------------------------------------
# Time: 2017-06-20 15:51:00
# -------------------------------------------
# the only one that shakes when mad? little ass legs shaking mph
# models are shaking and dropping their jobs
# this sopranos moby dick crossover looks interesting
# just realized this when watched dante reaction
# run that shit before and goons turn your whole ride upside down
# this whale literally looks like saying run
# just got heart attack reading this
# ahmadiyya muslim community strongly condemns the terrorist attack #finsburypark mosque our thoughts and pray
# hands shaking
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:52:00
# -------------------------------------------
# Tweets in this batch: 50
#
# -------------------------------------------
# Time: 2017-06-20 15:52:00
# -------------------------------------------
# stay the fuck outta their hood then
# well shaking hahahah
# lmfaoooo
# slippery tsunami that tongue
# warning signs point major earthquake san andreas fault
# stay the fuck outta their hood then
# joshi indian army #respect
# ffs give lost that primary landslide both these guys will and men don age well enoug
# nigga they are called killer whales not cuddly whales not mild mannered whales killer killer motherfuck
# great earthquake #assam subsidence the ground under the railway track between dum duma amp saikhowaghat
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:53:00
# -------------------------------------------
# Tweets in this batch: 57
#
# -------------------------------------------
# Time: 2017-06-20 15:53:00
# -------------------------------------------
# where were they radicalized
# youre beautiful jwiuhiue wow jongdae shaking his blonde
# panther whales out here hittin licks seen all
# wish had angel stand side shaking fear scared inside
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# stay the fuck outta their hood then
# panther whales out here hittin licks seen all
# nigga they are called killer whales not cuddly whales not mild mannered whales killer killer motherfuck
# this rape can take this literally shaking
# gold are you guys literally shaking?
# ...

# %% [markdown]
# ## Convert data to be classified

# %% [markdown]
# ## Start the streaming context

# %%
ssc.start()
ssc.awaitTermination(timeout=180)
# Out:
# -------------------------------------------
# Time: 2017-06-20 14:49:00
# -------------------------------------------
# Tweets in this batch: 97
#
# -------------------------------------------
# Time: 2017-06-20 14:49:00
# -------------------------------------------
# stay the fuck outta their hood then
# any teenation member beat quake champions will recieve till reach you lose will
# panther whales out here hittin licks seen all
# ara won shaking #whatsmynamestwin
# global unrest event underway west coast usa canada hit earthquake
# jonny amp thom play one off show macerata sferisterio august proceeds will help the restoration earthq
# after you predicted crooked hilly landslide you now are saying maybe and maybe not? lol
# blackpink shaking #krunk
# scoffs shaking her head please outside often both know that
# jay panorama reported people lived that tower survivors are really suggesting only are dead
# ...
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-11-562afce8b755> in <module>()
#       1 ssc.start()
# ----> 2 ssc.awaitTermination(timeout=180)
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/streaming/context.py in awaitTermination(self, timeout)
#     206             self._jssc.awaitTermination()
#     207         else:
# --> 208             self._jssc.awaitTerminationOrTimeout(int(timeout * 1000))
#     209
#     210     def awaitTerminationOrTimeout(self, timeout):
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/lib/py4j-0.10.3-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     317                 raise Py4JJavaError(
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#     321                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o33.awaitTerminationOrTimeout.
# : org.apache.spark.SparkException: An exception was raised by Python:
# Traceback (most recent call last):
#   File "/usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/streaming/util.py", line 65, in call
#     r = self.func(t, *rdds)
#   File "/usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/streaming/dstream.py", line 159, in <lambda>
#     func = lambda t, rdd: old_func(rdd)
#   File "<ipython-input-10-977c4d20cde0>", line 1, in <lambda>
#     tweet_df = mess.foreachRDD(lambda rdd: rdd.toDF("text"))
#   File "/usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/session.py", line 57, in toDF
#     return sparkSession.createDataFrame(self, schema, sampleRatio)
#   File "/usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/session.py", line 492, in createDataFrame
#     schema = _parse_datatype_string(schema)
#   File "/usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/types.py", line 845, in _parse_datatype_string
#     return _parse_basic_datatype_string(s)
#   File "/usr/local/src/spark/spark-2.0.2-bin-hadoop2.7/python/pyspark/sql/types.py", line 739, in _parse_basic_datatype_string
#     raise ValueError("Could not parse datatype: %s" % s)
# ValueError: Could not parse datatype: text
#
# 	at org.apache.spark.streaming.api.python.TransformFunction.callPythonTransformFunction(PythonDStream.scala:95)
# 	at org.apache.spark.streaming.api.python.TransformFunction.apply(PythonDStream.scala:78)
# 	at org.apache.spark.streaming.api.python.PythonDStream$$anonfun$callForeachRDD$1.apply(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.api.python.PythonDStream$$anonfun$callForeachRDD$1.apply(PythonDStream.scala:179)
# 	at org.apache.spark.streaming.dstream.ForEachDStream$$anonfun$1$$anonfun$apply$mcV$sp$1.apply$mcV$sp(ForEachDStream.scala:51)
# 	at org.apache.spark.streaming.dstream.ForEachDStream$$anonfun$1$$anonfun$apply$mcV$sp$1.apply(ForEachDStream.scala:51)
# 	at org.apache.spark.streaming.dstream.ForEachDStream$$anonfun$1$$anonfun$apply$mcV$sp$1.apply(ForEachDStream.scala:51)
# 	at org.apache.spark.streaming.dstream.DStream.createRDDWithLocalProperties(DStream.scala:415)
# 	at org.apache.spark.streaming.dstream.ForEachDStream$$anonfun$1.apply$mcV$sp(ForEachDStream.scala:50)
# 	at org.apache.spark.streaming.dstream.ForEachDStream$$anonfun$1.apply(ForEachDStream.scala:50)
# 	at org.apache.spark.streaming.dstream.ForEachDStream$$anonfun$1.apply(ForEachDStream.scala:50)
# 	at scala.util.Try$.apply(Try.scala:192)
# 	at org.apache.spark.streaming.scheduler.Job.run(Job.scala:39)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler$$anonfun$run$1.apply$mcV$sp(JobScheduler.scala:247)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler$$anonfun$run$1.apply(JobScheduler.scala:247)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler$$anonfun$run$1.apply(JobScheduler.scala:247)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:58)
# 	at org.apache.spark.streaming.scheduler.JobScheduler$JobHandler.run(JobScheduler.scala:246)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	at java.lang.Thread.run(Thread.java:748)
# -------------------------------------------
# Time: 2017-06-20 14:50:00
# -------------------------------------------
# Tweets in this batch: 61
#
# -------------------------------------------
# Time: 2017-06-20 14:50:00
# -------------------------------------------
# the whales are fed with our shit
# she shaking them titties girl yes
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# imagine this dance king hit the stage already shaking
# aggressive shaking down
# your area expertise sir
# got shaking hands during #mmvas slow hands
# ara won shaking #whatsmynamestwin
# your polls have never been close being right they were hillary would won landslide fire your polling agent lol
# residents flee after tsunami hit greenland following earthquake
# ...
#
# -------------------------------------------
# Time: 2017-06-20 14:51:00
# -------------------------------------------
# Tweets in this batch: 41
#
# -------------------------------------------
# Time: 2017-06-20 14:51:00
# -------------------------------------------
# imagine this dance king hit the stage already shaking
# omg after years finally got meet fucking shaking picture fine least looking
# qatar accuses uae supporting attacks new york gulf crisis deepens
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# earthquake banda sea
# dek qatar accuses uae supporting attacks new york gulf crisis deepens
# the fake left wants overthrow president who won landslide not counting illegal votes install globalist
# wth quakes rogue tsunami #yellowstone supervolcano all waking hell breaking loose? videos #paranormal
# gotta hear both sides yooo can see the dolphin them this pic
# helping residents affected #grenfell confidential free legal advice please get touch can help https
# ...
#
# -------------------------------------------
# Time: 2017-06-20 14:52:00
# -------------------------------------------
# Tweets in this batch: 61
#
# -------------------------------------------
# Time: 2017-06-20 14:52:00
# -------------------------------------------
# bye packing things leaving earth bcs this planet will gonna chaos noisy shaking bcs these two
# cnn tries conduct online trump hater poll but turns out landslide support for president
# the fake left wants overthrow president who won landslide not counting illegal votes install globalist
# #ge lost opportunity improve public understanding brexit according latest commentary from
# stay the fuck outta their hood then
# jonny amp thom play one off show macerata sferisterio august proceeds will help the restoration earthq
# beginning look lot like unmasking throughout whitehouse corrruption disruption amp bribery amp never
# jay panorama reported people lived #grenfelltower there are reported survivors yet authorities say only are missi
# panther whales out here hittin licks seen all
# panther whales out here hittin licks seen all
# ...
#
# -------------------------------------------
# Time: 2017-06-20 14:53:00
# -------------------------------------------
# Tweets in this batch: 43
#
# -------------------------------------------
# Time: 2017-06-20 14:53:00
# -------------------------------------------
# qatar accuses uae supporting attacks new york gulf crisis deepens
# the economist europes saviour? via
# air #nowplaying landslide original radio ashford
# jay panorama reported people lived #grenfelltower there are reported survivors yet authorities say only are missi
# qatar accuses uae supporting attacks new york gulf crisis deepens
# solar alert quake watch peaks yellowstone news june via
# panther whales out here hittin licks seen all
# nigga they are called killer whales not cuddly whales not mild mannered whales killer killer motherfuck
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:00:00
# -------------------------------------------
# Tweets in this batch: 52
#
# -------------------------------------------
# Time: 2017-06-20 15:00:00
# -------------------------------------------
# sounds like something jamaican killer whales would affi adapt when times get rough pon utes dem nyam next
# wings short films gonna nothing compared what the budget and production value for this going honestly sha
# not planning out just saying miss kissing you let out scoff shaking his head
# cnn tries conduct online trump hater poll but turns out landslide support for president
# focused niggas out here gettin extorted whales lmfaoooooooooooooooo
# shaking
# free willy out here gettin his bet they all got the rip shamoo tats too
# gonna california days shaking boots
# research examine aftermath earthquake caused blackout the press #earthquake
# reservoir water weight blamed for arkansas earthquake swarm paradise post #earthquake
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:01:00
# -------------------------------------------
# Tweets in this batch: 38
#
# -------------------------------------------
# Time: 2017-06-20 15:01:00
# -------------------------------------------
# elf this woman has like the best job the world how does she it? would shaki
# remember blair hands shaking put his glasses read document
# landslide for trump weakest popular vote weakest
# nbin such cute ship also the spiciest ship the best both worlds hannah montana shaking her grave rip
# was that earthquake did you just rock world
# they sick our shit that for their homies stuck sea world
# this helps give people better heads that tropical system may making landfall the near future
# panther whales out here hittin licks seen all
# landslide footage from roundu valley gilgit baltistan via
# the modeling industry shaking are actual models
# ...
#
# -------------------------------------------
# Time: 2017-06-20 15:02:00
# -------------------------------------------
# Tweets in this batch: 54
#
# -------------------------------------------
# Time: 2017-06-20 15:02:00
# -------------------------------------------
# cosmetology licenses are shaking
# tearway lmao keep shaking your head
# qatar accuses uae supporting attacks new york gulf crisis deepens
# national outreach direct usman ahmad speaking about #grenfelltower relief efforts
# they are shaking their heads the lying msm and fools like you that believe the lying msm
# snorlax available until lick earthquake
# alvin you drunk
# boats better have fish
# panther whales out here hittin licks seen all
# gangs aggressive killer whales are shaking down alaska fishing boats for their fish report
# ...

# %% [markdown]
# ## Sort the author count

# %%
author_counts_sorted_dstream = author_counts.transform(\
  (lambda foo:foo\
   .sortBy(lambda x:( -x[1]))))

# %%
author_counts_sorted_dstream.pprint()

# %% [markdown]
# ## Get top 5 authors by tweet count

# %%
top_five_authors = author_counts_sorted_dstream.transform\
  (lambda rdd:sc.parallelize(rdd.take(5)))
top_five_authors.pprint()

# %% [markdown]
# ## Get authors with more than one tweet, or whose username starts with 'a'

# %%
filtered_authors = author_counts.filter(lambda x:\
                                                x[1]>1 \
                                                or \
                                                x[0].lower().startswith('rm'))

# %%
filtered_authors.transform\
  (lambda rdd:rdd\
  .sortBy(lambda x:-x[1]))\
  .pprint()

# %% [markdown]
# ## List the most common words in the tweets

# %%
parsed.\
    flatMap(lambda tweet:tweet['text'].split(" "))\
    .countByValue()\
    .transform\
      (lambda rdd:rdd.sortBy(lambda x:-x[1]))\
    .pprint()
