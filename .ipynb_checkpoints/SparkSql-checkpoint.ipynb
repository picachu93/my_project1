# %% [markdown]
# ## Import packages

# %%
from pyspark.sql import DataFrame
from pyspark.ml import *

# %% [markdown]
# ## Load dataset as DataFrame from JSON

# %%
# A JSON dataset is pointed to by path.
# The path can be either a single text file or a directory storing text files
path = "data/nepal_pos.json"
tweetsDF = spark.read.json(path)

# %%
# The inferred schema can be visualized using the printSchema() method
tweetsDF.printSchema()
# Out:
# root
#  |-- contributors: string (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- entities: struct (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- symbols: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- urls: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- user_mentions: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- screen_name: string (nullable = true)
#  |-- extended_entities: struct (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- additional_media_info: struct (nullable = true)
#  |    |    |    |    |-- monetizable: boolean (nullable = true)
#  |    |    |    |    |-- source_user: struct (nullable = true)
#  |    |    |    |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |    |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- entities: struct (nullable = true)
#  |    |    |    |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- favourites_count: long (nullable = true)
#  |    |    |    |    |    |-- follow_request_sent: boolean (nullable = true)
#  |    |    |    |    |    |-- followers_count: long (nullable = true)
#  |    |    |    |    |    |-- following: boolean (nullable = true)
#  |    |    |    |    |    |-- friends_count: long (nullable = true)
#  |    |    |    |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |    |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |    |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |    |    |-- listed_count: long (nullable = true)
#  |    |    |    |    |    |-- location: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- notifications: boolean (nullable = true)
#  |    |    |    |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |    |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |    |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |    |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |    |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |    |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |    |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |    |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |    |    |    |-- statuses_count: long (nullable = true)
#  |    |    |    |    |    |-- time_zone: string (nullable = true)
#  |    |    |    |    |    |-- translator_type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- utc_offset: long (nullable = true)
#  |    |    |    |    |    |-- verified: boolean (nullable = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- favorited: boolean (nullable = true)
#  |-- geo: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- id_str: string (nullable = true)
#  |-- in_reply_to_screen_name: string (nullable = true)
#  |-- in_reply_to_status_id: long (nullable = true)
#  |-- in_reply_to_status_id_str: string (nullable = true)
#  |-- in_reply_to_user_id: long (nullable = true)
#  |-- in_reply_to_user_id_str: string (nullable = true)
#  |-- is_quote_status: boolean (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- place: struct (nullable = true)
#  |    |-- bounding_box: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- contained_within: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- country: string (nullable = true)
#  |    |-- country_code: string (nullable = true)
#  |    |-- full_name: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- place_type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- possibly_sensitive: boolean (nullable = true)
#  |-- quoted_status: struct (nullable = true)
#  |    |-- contributors: string (nullable = true)
#  |    |-- coordinates: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- symbols: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- urls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |-- extended_entities: struct (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- additional_media_info: struct (nullable = true)
#  |    |    |    |    |    |-- monetizable: boolean (nullable = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favorite_count: long (nullable = true)
#  |    |-- favorited: boolean (nullable = true)
#  |    |-- geo: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |-- is_quote_status: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- bounding_box: struct (nullable = true)
#  |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- contained_within: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- country_code: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- place_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |-- quoted_status_id: long (nullable = true)
#  |    |-- quoted_status_id_str: string (nullable = true)
#  |    |-- retweet_count: long (nullable = true)
#  |    |-- retweeted: boolean (nullable = true)
#  |    |-- scopes: struct (nullable = true)
#  |    |    |-- followers: boolean (nullable = true)
#  |    |-- source: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- truncated: boolean (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- favourites_count: long (nullable = true)
#  |    |    |-- follow_request_sent: boolean (nullable = true)
#  |    |    |-- followers_count: long (nullable = true)
#  |    |    |-- following: boolean (nullable = true)
#  |    |    |-- friends_count: long (nullable = true)
#  |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- listed_count: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- notifications: boolean (nullable = true)
#  |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- statuses_count: long (nullable = true)
#  |    |    |-- time_zone: string (nullable = true)
#  |    |    |-- translator_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- utc_offset: long (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |-- quoted_status_id: long (nullable = true)
#  |-- quoted_status_id_str: string (nullable = true)
#  |-- retweet_count: long (nullable = true)
#  |-- retweeted: boolean (nullable = true)
#  |-- retweeted_status: struct (nullable = true)
#  |    |-- contributors: string (nullable = true)
#  |    |-- coordinates: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- symbols: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- urls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |-- extended_entities: struct (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- additional_media_info: struct (nullable = true)
#  |    |    |    |    |    |-- monetizable: boolean (nullable = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favorite_count: long (nullable = true)
#  |    |-- favorited: boolean (nullable = true)
#  |    |-- geo: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |-- is_quote_status: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- bounding_box: struct (nullable = true)
#  |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- contained_within: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- country_code: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- place_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |-- quoted_status: struct (nullable = true)
#  |    |    |-- contributors: string (nullable = true)
#  |    |    |-- coordinates: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- media: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- symbols: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- extended_entities: struct (nullable = true)
#  |    |    |    |-- media: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- favorite_count: long (nullable = true)
#  |    |    |-- favorited: boolean (nullable = true)
#  |    |    |-- geo: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |    |-- is_quote_status: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- place: string (nullable = true)
#  |    |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |    |-- retweet_count: long (nullable = true)
#  |    |    |-- retweeted: boolean (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- truncated: boolean (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- entities: struct (nullable = true)
#  |    |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- favourites_count: long (nullable = true)
#  |    |    |    |-- follow_request_sent: boolean (nullable = true)
#  |    |    |    |-- followers_count: long (nullable = true)
#  |    |    |    |-- following: boolean (nullable = true)
#  |    |    |    |-- friends_count: long (nullable = true)
#  |    |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |-- listed_count: long (nullable = true)
#  |    |    |    |-- location: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- notifications: boolean (nullable = true)
#  |    |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |    |-- protected: boolean (nullable = true)
#  |    |    |    |-- screen_name: string (nullable = true)
#  |    |    |    |-- statuses_count: long (nullable = true)
#  |    |    |    |-- time_zone: string (nullable = true)
#  |    |    |    |-- translator_type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- utc_offset: long (nullable = true)
#  |    |    |    |-- verified: boolean (nullable = true)
#  |    |-- quoted_status_id: long (nullable = true)
#  |    |-- quoted_status_id_str: string (nullable = true)
#  |    |-- retweet_count: long (nullable = true)
#  |    |-- retweeted: boolean (nullable = true)
#  |    |-- source: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- truncated: boolean (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- description: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- favourites_count: long (nullable = true)
#  |    |    |-- follow_request_sent: boolean (nullable = true)
#  |    |    |-- followers_count: long (nullable = true)
#  |    |    |-- following: boolean (nullable = true)
#  |    |    |-- friends_count: long (nullable = true)
#  |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |-- has_extended_profile: boolean (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- listed_count: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- notifications: boolean (nullable = true)
#  |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- statuses_count: long (nullable = true)
#  |    |    |-- time_zone: string (nullable = true)
#  |    |    |-- translator_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- utc_offset: long (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |-- source: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- truncated: boolean (nullable = true)
#  |-- user: struct (nullable = true)
#  |    |-- contributors_enabled: boolean (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- default_profile: boolean (nullable = true)
#  |    |-- default_profile_image: boolean (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- description: struct (nullable = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- url: struct (nullable = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favourites_count: long (nullable = true)
#  |    |-- follow_request_sent: boolean (nullable = true)
#  |    |-- followers_count: long (nullable = true)
#  |    |-- following: boolean (nullable = true)
#  |    |-- friends_count: long (nullable = true)
#  |    |-- geo_enabled: boolean (nullable = true)
#  |    |-- has_extended_profile: boolean (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- is_translation_enabled: boolean (nullable = true)
#  |    |-- is_translator: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- listed_count: long (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- notifications: boolean (nullable = true)
#  |    |-- profile_background_color: string (nullable = true)
#  |    |-- profile_background_image_url: string (nullable = true)
#  |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |-- profile_background_tile: boolean (nullable = true)
#  |    |-- profile_banner_url: string (nullable = true)
#  |    |-- profile_image_url: string (nullable = true)
#  |    |-- profile_image_url_https: string (nullable = true)
#  |    |-- profile_link_color: string (nullable = true)
#  |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |-- profile_text_color: string (nullable = true)
#  |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |-- protected: boolean (nullable = true)
#  |    |-- screen_name: string (nullable = true)
#  |    |-- statuses_count: long (nullable = true)
#  |    |-- time_zone: string (nullable = true)
#  |    |-- translator_type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- utc_offset: long (nullable = true)
#  |    |-- verified: boolean (nullable = true)

# %%
# Creates a temporary view using the DataFrame
tweetsDF.createOrReplaceTempView("tweets")

# %%
# SQL statements can be run by using the sql methods provided by spark
tweetTextsDF = spark.sql("SELECT id,text FROM tweets")
tweetTextsDF.count()
#tweetTextsDF.show()
# Out:
# 4687

# %% [markdown]
# ## Read from text file

# %%
from pyspark.sql import Row

# %%
# Load a text file and convert each line to a Row.
lines = sc.textFile("data/nepal_pos_tot.csv")
header = lines.first() #extract header
lines = lines.filter(lambda row : row != header)   #filter out header
parts = lines.map(lambda l: l.split(","))
tweets = parts.map(lambda p: Row(tweet_id=p[0], tweet_text=p[1], label=p[2]))

# Infer the schema, and register the DataFrame as a table.
schemaTweets = spark.createDataFrame(tweets)
schemaTweets.createOrReplaceTempView("tweets")
# SQL can be run over DataFrames that have been registered as a table.
positive_tweets = spark.sql("SELECT tweet_text FROM tweets")
tweetTexts = positive_tweets.rdd.map(lambda p: "Text: " + p.tweet_text).collect()
for tweet_text in tweetTexts:
    print(tweet_text)
# Out:
# Text: "#indiawithnepal my thoughts with those affected in nepal quake very strong tremors in padrauna kushinagar too we re just bordering nepal"
# Text: "nepal earthquake in maps tweets and pictures"
# Text: "#news nepal home ministry says at least people killed in the earthquake nepal home ministry says #tu"
# Text: "#earthquake helpline numbers of the indian embassy in nepal \n+ \n\n+"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "#earthquakeinnepal\nhelpline numbers of indian embassy in kathmandu \n\n \n\nplease help by re tweeting"
# Text: "divastating earthquake shakes the soul of the people #nepal"
# Text: "#news tv dead injured in bangladesh from nepal quake tv report dead injured in banglades #tu"
# Text: "pictures from kathmandu show damage of magnitude #earthquake"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "#breaking at least killed in nepal earthquake home ministry"
# Text: "magnitude quake hits nepal causing big damage injuries the damage includes toppled walls and collapsed"
# Text: "earthquake km nne of nagarkot nepal apr at epicenter ago depth km"
# Text: "witness nepal quake was massive kathmandu is crumbling"
# Text: "people finder live quake map emergency numbers #nepal"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "indian air force is ready to help the people of nepal #salutetoarmy\n\n#earthquake #indiawithnepal"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "it is also climbing season and there are many sherpa villages near everest over avalanches being reported #nepal #nepalearthquake"
# Text: "key facts about nepal site of magnitude quake"
# Text: "magnitude earthquake hits nepal"
# Text: "the most devastating news about nepal praying"
# Text: "express solidarity amp stand with nepal in this hour of distress will be our endeavor to extend all support amp assistance to those affected"
# Text: "shocking picture of the earthquake in nepal"
# Text: "pictures from kathmandu show damage of magnitude #earthquake reports of injuries"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "police say at least people killed after the magnitude earthquake in nepal"
# Text: "images from everest base camp by utm student azim afif following the quake #kathmandu utm camp is safe"
# Text: "awful sight kathmandu darbar square unesco world heritage site in ruins after today earthquake rt"
# Text: "thoughts and prayers with people affected by the tragic #earthquake in nepal amp in india the details of death amp casualties are horrifying"
# Text: "only positive half day available for rescue ops hope it doesn rain #nepal"
# Text: "pictures from kathmandu show damage of magnitude #earthquake reports of injuries"
# Text: "more than people killed in powerful nepal earthquake say government officials and police"
# Text: "emergency contact numbers for nepal spread the word guys please"
# Text: "pakistan offers assistance to nepal and india in wake of the devastating earthquake"
# Text: "prayers for the affected people across #southasia by the horrible #earthquake \n#india #bangladesh #pakistan #afganistan #bhutan #nepal"
# Text: "#breaking at least killed in nepal earthquake home ministry"
# Text: "mea opens hour control room in #delhi for queries regarding the nepal earthquake \n\n"
# Text: "nepal #earthquake triggers #avalanche on north mt qomolangma everest altitude in china tibet climbers no casualty"
# Text: "emergency contact numbers in nepal"
# Text: "google person finder link for india and #nepal #earthquake #kathmanduquake"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "strong earthquake strikes nepal"
# Text: "may god gives courage to the people of nepal who are fighting from #earthquake"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "#msghelpearthquakevictims shocked hearing earthquake in nepal some parts of india pray to god to save his children"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "in the wake of the #earthquake in nepal hour control room has been set up by the mea"
# Text: "breaking news earthquake hits nepal causing damage injuries"
# Text: "thoughts with the people near the earthquake in nepal"
# Text: "here are the emergency contact numbers for nepal share help our prayers are with all in nepal"
# Text: "magnitude earthquake hits nepal"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "nepal quake magnitude tremor hits near kathmandu"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "#latest #nepal kantipur tv shows at least bodies lined up on ground after earthquake\n"
# Text: "#msghelpearthquakevictims shocked hearing earthquake in nepal some parts of india pray to god to save his children"
# Text: "hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "globmaster hercules to be sent to nepal for rescue mission #earthquake"
# Text: "just in gt people work to free man trapped by rubble in #kathmandu after earthquake hits #nepal"
# Text: "buildings collapse in #kathmandu after #earthquake hits #nepal casualties are feared"
# Text: "strong earthquake rocks nepal damages kathmandu many feared killed tremors felt as far away as delhi"
# Text: "nepal helpline for earthquake"
# Text: "nepal earthquake in maps tweets and pictures"
# Text: "magnitude quake hits nepal causing big damage injuries the damage includes toppled walls and collapsed"
# Text: "ah shit"
# Text: "feel bad and sorry for over reported deaths due to earthquake in nepal praying for their souls to rest in peace my heartfelt condolences"
# Text: "hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "collapsed buildings at lalitpur on the outskirts of kathmandu #nepalquake"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "#nepalquakes\nmore than killed in powerful nepal #earthquake say govt officials and police"
# Text: "our thoughts are with the people of #nepal who have suffered an earthquake with magnitude of #prayfornepal #naturaldisaster"
# Text: "helpline numbers to contact indian embassy in nepal"
# Text: "we can imagine the pain #nepal is going through right now experienced same situation in #balakot\n#earthquake \ncondolences with nepal"
# Text: "latest killed in magnitude #nepal earthquake local police"
# Text: "spread the word"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "rt more than killed in powerful nepal #earthquake say government officials and police rest and peace"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "over hundred reported death due to earthquake in nepal god help them \n\nmay their soul rest in peace \n\n#earthquakeinnepal"
# Text: "pm narendra modi speaks to nepal president after magnitude earthquake hits nepal\n"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "two major quakes rattle nepal historic dharahara tower collapses deaths reported in india\n"
# Text: "big expresses shock over nepal quake reminisces mahaan shoot click here gt #khufiabollywood"
# Text: "nepal police says dead in quake according to initial estimate"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "significant damage in nepal after major magnitude earthquake strikes"
# Text: "foxnews breaking at least people dead killed in earthquake nepal home ministry says"
# Text: "god bless everyone in nepal"
# Text: "more than people were killed in the capital kathmandu following the powerful earthquake official in nepal"
# Text: "one hour before nepal earthquake small temple behind me completely collapsed absolutely surreal #nepalquake"
# Text: "breaking significant damage in kathmandu after major earthquake strikes nepal"
# Text: "strong earthquake rocks nepal damages kathmandu"
# Text: "emergency contact numbers for nepal spread the word guys please"
# Text: "an injured child receives treatment outside medicare hospital in kathmandu image ap"
# Text: "shocking news the earthquake damage the beautiful #nepal hope everything is well now there"
# Text: "shocking news of the #earthquake from nepal praying for the safety of all affected"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "over killed in earthquake nepal home ministry pti"
# Text: "rescuers clear the debris at durbar sqaure after an earthquake in kathmandu image ap"
# Text: "missionaries smell potential souls for harvesting reach nepal \nmohan bhagwat proved right their seva is mission"
# Text: "since there is less free and open space people are gathering to road #earthquake #nepal"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "awful sight kathmandu darbar square unesco world heritage site in ruins after today earthquake rt"
# Text: "thoughts and prayers go to nepal"
# Text: "breaking at least killed in nepal earthquake home ministry read"
# Text: "in pictures man is lucky to be rescued as massive earthquake hits nepal"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "prayers go out to all those affected by the earthquake #earthquake #nepal"
# Text: "story building collapsed in sat tale kapan #kathmandu #nepal"
# Text: "breaking at least people killed in magnitude earthquake in nepal"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "at least people killed in kathmandu in china in pokhara at mount everest base camp and in india frm #earthquake report"
# Text: "strong earthquake strikes nepal"
# Text: "update hundreds feared dead in #nepal quake says official at #nepals embassy in #newdelhi"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "earthquake in nepal devastating loss of life property seems enormous govt people of bharat will do everything to help our brethren"
# Text: "strong earthquake rocks nepal damages kathmandu\n"
# Text: "breaking more than killed in #nepal earthquake says interior ministry"
# Text: "#breakingnews at least people killed in magnitude #earthquake in #nepal"
# Text: "earthquake km nnw of nagarkot nepal apr at epicenter ago depth km"
# Text: "nepal earthquake triggers everest avalanche climbers at risk"
# Text: "shame of you you are posting fake images of kathmandu earthquake \n#beshramndtv #earthquake"
# Text: "thoughts to those in #nepal devastating"
# Text: "magnitude earthquake rocks nepal leveling buildings causing an avalanche on mt everest"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "my heart goes out to all those experiencing earthquake and aftershocks in nepal stay strong look out for each other"
# Text: "nepal earthquake first picture india tv news #indiatv va"
# Text: "breaking at least people killed in magnitude earthquake in nepal"
# Text: "some friends in sydney who come from #nepal can reach their families my prayers are with them #nepalearthquake #nepalquake #earthquake"
# Text: "#nepalearthquake major aftershocks measuring amp in gorkha amp rasuwa resp within mins of first #earthquake vi parashar"
# Text: "verma okay lets just pray for nepal"
# Text: "#earthquake in nepal leads to heavy destruction in agra\nwatch here"
# Text: "more than people killed in powerful nepal earthquake say government officials and police"
# Text: "helpline numbers for friends in #nepal stuck in tremors plz rt or re post offl"
# Text: "pray for nepal"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "tragic news of the earthquake in nepal pray the nation and the people find the strength to cope with this terrible tragedy mr"
# Text: "my heart is with you nepal \n\nyet another reminder that life is short and unpredictable and we ve got to live the best we can while we can"
# Text: "list of doctors and hospitals in nepal"
# Text: "the soil of kathmandu valley is an ancient lakebed that produces high intensity vibrations during quake"
# Text: "th earthquake just hit nepal intensity again around \ncasualty mark reaching to sad"
# Text: "my prayers stand by the ppl living in nepal \ni hope everyone is fine"
# Text: "latest video"
# Text: "strong #earthquake rocks #nepal damages #kathmandu"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "nepal #earthquake latest \n\n reports of avalanches in everest\n temples flattened\n unknown numbers killed amp injured"
# Text: "#usnews key facts about nepal site of magnitude quake #news"
# Text: "more than people killed in powerful nepal earthquake say government officials and police"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "#prayforkathmandu man being rescued after massive #earthquake in #nepal #nepalearthquake all we can do is #pray"
# Text: "breaking at least people killed in magnitude earthquake in nepal"
# Text: "just read abt the earthquake in nepal prayers with those affected pls help in any way can start by sharing this"
# Text: "sad see this image of extensive damage due to the #earthquake in nepal my prayers with the victims amp their families"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "bodies seen after nepal quake topples landmark tower"
# Text: "india to rush relief team to nepal to assist in earthquake relief reports times now #earthquake"
# Text: "mea opens hour control room for queries regarding the nepal #earthquake numbers \n+ \n+ \n+"
# Text: "missionaries smell potential souls for harvesting reach nepal \nmohan bhagwat proved right their seva is mission"
# Text: "rss volunteers are leaving for nepal \n#earthquake"
# Text: "nepal quake triggers everest avalanche climbers at risk"
# Text: "hope nepal ppl safe be safe and other earthquake affected area"
# Text: "what horrid year for nepal was there last year this time reporting everest avalanche then annapurna storm in october now this"
# Text: "usgs reports #earthquake km nnw of nagarkot nepal on utc #quake"
# Text: "earthquake in nepal in pictures"
# Text: "#earthquake helpline numbers of the indian embassy in nepal \n+ \n\n+"
# Text: "#nepal #earthquake hope all my friends are well love this country and its people"
# Text: "thoughts with colleagues in kathmandu all oxfam staff safe but reports of widespread damage #nepalearthquake"
# Text: "terrible news from #kathmandu thinking of those suffering and hope my friends in the region are okay"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "nepal home ministry says at least people killed in the earthquake nepal home ministry says at least"
# Text: "earthquake hkt in nepal"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "avalanche sweeps everest in nepal injured ap #news"
# Text: "mea opens hour control room for queries regarding the nepal #earthquake \nnumbers \n+ \n+ \n+"
# Text: "big expresses shock over nepal quake reminisces mahaan shoot click here gt #daddyslilgirlpc"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "nepal earthquake triggers avalanches in mount everest region reports"
# Text: "st images coming frm nepal aftr the devastating earthquake day may all are safe there"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "tv dead injured in bangladesh from nepal quake"
# Text: "may allah be with the people in nepal and ease their difficulty may all be well with them #nepal"
# Text: "kathmandu patan district old royal square devastated"
# Text: "magnitude earthquake hits #nepal the numbers injured and killed still not known"
# Text: "at least killed in magnitude quake in nepal ap #news"
# Text: "latest pics sent to ani from kathmandu of #earthquake aftermath"
# Text: "due to bulding collaps people died in eastern part of nepal in sunsari in okhaldhunga and in solu dist according to police"
# Text: "nepal #earthquake latest \n\n reports of avalanches in everest\n temples flattened\n unknown numbers killed amp injured"
# Text: "ve never felt an earthquake like this in my entire life biggest in yrs bbc #nepal #nepalearthquake"
# Text: "hopefully everyone is safe in thamel and the rest of nepal #earthquake"
# Text: "prayers for people in nepal we stand by them in this hour of need"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "#nepalquake #nepal avalanche on everest south side climbers went missing"
# Text: "police say at least people killed after the magnitude earthquake in nepal"
# Text: "to share as much as possible amp help people in nepal #earthquakehelpline"
# Text: "km ese of lamjung nepal highly informative read on seismic history of himalayas"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "#nepalearthquake \npm \nspoken with\nnepal prez pm\ncm of \nbihar\nmp\nwb\nsikkim\nup\nhigh level meeting\nndrf dispatched\nwow"
# Text: "earthquake in nepal devastating loss of life property seems enormous govt people of bharat will do everything to help our brethren"
# Text: "breaking magnitude of #nepal earthquake upgraded to"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "more than killed in nepal #earthquake"
# Text: "in nepal #earthquake at least people are expected dead dead bodies brought to kathmandu hospital via"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "extremely heart wrecking to learn that more than people are dead in nepal may their souls rest in peace #earthquake"
# Text: "nepal home ministry says at least people killed in the earthquake nepal home ministry says at least"
# Text: "nepal #earthquake latest \n\n reports of avalanches in everest\n temples flattened\n unknown numbers killed amp injured"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "over killed in earthquake nepal home ministry pti"
# Text: "#earthquake helpline numbers of the indian embassy in nepal \n+ \n\n+"
# Text: "list of doctors and hospitals in nepal"
# Text: "nepal quake triggers everest avalanche climbers at risk"
# Text: "truly awful sight kathmandu darbar square unesco world heritage site in ruins after today earthquake"
# Text: "earthquake in nepal devastating loss of life property seems enormous govt people of bharat will do everything to help our brethren"
# Text: "police say at least people killed after the magnitude earthquake in nepal"
# Text: "the government people of pakistan express solidarity with the affected people of nepal and india and offer all possible help"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "#msghelpearthquakevictims shocked hearing earthquake in nepal some parts of india pray to god to save his children"
# Text: "kathmandu darbar square unesco world heritage site in ruins after today #earthquake pic"
# Text: "buildings collapse in nepal capital after quake witnesses"
# Text: "nepal #earthquake latest \n\n reports of avalanches in everest\n temples flattened\n unknown numbers killed amp injured"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "breaking news\n\n dead injured in bangladesh from nepal earthquake at least killed in nepal\n\n ptv"
# Text: "latest pics sent to ani from kathmandu of #earthquake aftermath"
# Text: "prayers for the wellbeing of people in nepal and other earthquake affected areas"
# Text: "help lines numbers plz share #nepal #aranikohighway #lokanthali #earthquake"
# Text: "today earthquake data for #nepal via download it and explore for yourself \n\n"
# Text: "list of doctors and hospitals in nepal"
# Text: "update humanitarian crisis in nepal dead toll may rises to prayers amp thought for nepalese friends"
# Text: "more than people killed in powerful nepal earthquake say government officials and police"
# Text: "at least killed in magnitude quake in nepal kathmandu nepal ap nepal home ministr lt full story"
# Text: "strong earthquake rocks nepal damages kathmandu"
# Text: "kathmandus patan durbar square before and after the #nepalearthquake"
# Text: "ve never felt an earthquake like this in my entire life biggest in yrs bbc #nepal #nepalearthquake"
# Text: "tv dead injured in bangladesh from nepal quake"
# Text: "my prayers go to all those affected by the magnitude earthquake in nepal may god give them strength and patience to get through"
# Text: "describes run from his tent when avalanche struck mt everest after nepal earthquake"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "strong earthquake rocks nepal damages kathmandu"
# Text: "nepal #earthquake developments follow our live blog"
# Text: "pictures from kathmandu show damage of magnitude #earthquake reports of injuries"
# Text: "avalanche sweeps everest in nepal injured kathmandu nepal ap senior mountai"
# Text: "kathmandu patan district old royal square devastated \n\n#nepalearthquake #earthquake"
# Text: "at least killed in magnitude quake in nepal"
# Text: "#nepal avalanche fell on the himalayan mountaineer who climb everest many climbers missing"
# Text: "strong earthquake strikes nepal"
# Text: "hundreds feared dead as magnitude earthquake hits nepal"
# Text: "sister describes quake as absolutely huge in bhaktapur #nepal #nepalquake"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "my prayers stand by the ppl living in nepal \ni hope everyone is fine"
# Text: "history is now in dust #earthquake #nepal"
# Text: "ve never felt an earthquake like this in my entire life biggest in yrs bbc #nepal #nepalearthquake"
# Text: "rip those who lost their lives plz help nepal"
# Text: "at least killed in magnitude quake in nepal kathmandu nepal ap nepal home ministry says at leas"
# Text: "nepal helpline numbers plz do share"
# Text: "tv dead injured in bangladesh from nepal quake #nationalsiblingsday"
# Text: "indian army and air force on standby to rush to nepal if needed says mod #nepalearthquake"
# Text: "strong earthquake rocks nepal damages kathmandu via"
# Text: "dead injured in bangladesh from earthquake originating in nepal ap #earthquake more"
# Text: "in pictures man is lucky to be rescued as massive earthquake hits nepal"
# Text: "earthquake in nepal"
# Text: "#earthquake\n#kathmandu darbar square unesco world heritage site in ruins after today #earthquake"
# Text: "medical treatment at chabel operating on the road #earthquake #kathmandu #nepal"
# Text: "at least killed in magnitude quake in nepal #nationalsiblingsday"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "our thoughts and concerns are with all those involved and their families #quakeupdate #nepal #nepalearthquake"
# Text: "pm calls up cms of up bihar wb amp sikkim pms of nepal amp bhutan to assure all possible assistance bhutan to send rescue team to nepal"
# Text: "more than people killed in powerful nepal earthquake say government officials and police"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "magnitude #earthquake hits #nepal causing huge damage injuries #nepalearthquake"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "breaking nepal #earthquake triggers #avalanche on north mt qomolangma everest altitude in china tibet climbers no casualty"
# Text: "nepal quake search for survivors with people missing in dharahara tower collapse\n"
# Text: "#msghelpearthquakevictims bcz is concerned about the situation of\n\nm km of lamjung nepal"
# Text: "hope no damage to pashupatinath and boudhunath #nepal"
# Text: "iaf hercules on stand by team of doctors ndrf jcbs food water medicines being put together to send to nepal"
# Text: "pm nawaz expresses grief over the earthquake in #nepal\n"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "dead injured in bangladesh from earthquake originating in nepal ap #earthquake more"
# Text: "ve never felt an earthquake like this in my entire life biggest in yrs bbc #nepal #nepalearthquake"
# Text: "airport in nepal is closed till further notice"
# Text: "avalanche sweeps everest in nepal injured kathmandu nepal ap senior mountaineering guide says an"
# Text: "#msghelpearthquakevictims shocked hearing earthquake in nepal some parts of india pray to god to save his children"
# Text: "#nepalquakes\nmore than killed in powerful nepal #earthquake say govt officials and police"
# Text: "india should extend highest possible support to nepal in handling their disaster due to today earthquake"
# Text: "indian embassy helpline nepal amp other numbers"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "care staff in kathmandu walls are broken down ppl are traumatised still strong aftershocks #nepalquake"
# Text: "earthquake in bhantawari nepal"
# Text: "at least killed in magnitude quake in nepal kathmandu nepal ap nepal hom"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "#avalanches are reported in the mount everest region at the height of #climbing season #nepal #earthquake"
# Text: "bodies removed from kathmandu historic dharahara tower after it collapses in earthquake"
# Text: "kartikeyan indian embassy helpline nepal +\nand other numbers #earthquake"
# Text: "hope everyone is safe in nepal amp india due to earthquake please refer to all the emergency numbers doing"
# Text: "#earthquake just happened in #nepal we felt the tremors in #lucknow #delhi and #kolkata we re okay but pray for people in nepal"
# Text: "#msghelpearthquakevictims shocked hearing earthquake in nepal some parts of india pray to god to save his children"
# Text: "breaking rss swayamsevaks already heading to nepal for help amp rescue efforts"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "helpline numbers for friends in #nepal stuck in tremors plz rt or re post offl"
# Text: "the dharahara tower of nepal has collapsed with people suspected buried"
# Text: "avalanche sweeps everest in nepal injured #nationalsiblingsday"
# Text: "people are in the streets amp very afraid there ve been very big aftershocks bbc #nepal #nepalearthquake"
# Text: "tv dead injured in bangladesh from nepal quake dhaka bangladesh ap tv report says that two peo"
# Text: "and this is how spreads white lies and concocts news in their studios image of mexico as of kathmandu"
# Text: "wow just showed the same philippines earthquake picture and said it from kathmandu on tv utter stupidity"
# Text: "some friends in sydney who come from #nepal can reach their families my prayers are with them #nepalearthquake #nepalquake #earthquake"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "heart breaking news coming from nepal th century dharahara bhimsen tower has collapsed amp ppl trapped"
# Text: "please spread the word by retweeting it #nepalearthquake #nepalquake #earthquake"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "nepal earthquake historic tower collapses killing several latest updates here"
# Text: "some bimbos are messaging me asking did you feel the tremors in bbay?cus apparently there was an earthquake in nepal amazing"
# Text: "#breaking at least people killed in #nepal earthquake officials in capital #kathmandu say #kathmanduquake"
# Text: "update humanitarian crisis in nepal dead toll may rises to prayers amp thought for nepalese friends"
# Text: "strong earthquake strikes nepal #bbc"
# Text: "tv dead injured in bangladesh from nepal quake dhaka bangladesh ap tv"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "#ap avalanche sweeps everest in nepal injured kathmandu nepal ap senior mountaineering guide says"
# Text: "chitttt"
# Text: "ap key facts about nepal site of magnitude quake"
# Text: "when they mock at tragedy hve only two adjectives for bhakts sanghis \nu all sick amp sadist #earthquake #nepal"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "significant damage in nepal after major magnitude earthquake strikes"
# Text: "people finder help find people #earthquake #nepal"
# Text: "witness dust rises amid rubble in bhaktapur near kathmandu after major earthquake aftershocks continue"
# Text: "google has launched person finder instance to help track missing persons for the #nepal #earthquake\n"
# Text: "helpline numbers to contact indian embassy in nepal kathmandu are \n#earthquake\n"
# Text: "emergency numbers for nepal kindly rt amp spread so that it reaches to those in need of earthquake relief"
# Text: "it hard to see #kathmandu devastated by #earthquake most of historical places gone including #dharahara landmark of kathmandu"
# Text: "more than people killed in powerful nepal earthquake say government officials and police"
# Text: "tv dead injured in bangladesh from nepal quake dhaka bangladesh ap tv report says #slavetrade"
# Text: "globmaster hercules to be sent to nepal for rescue mission #earthquake"
# Text: "ve never felt an earthquake like this in my entire life biggest in yrs bbc #nepal #nepalearthquake"
# Text: "home minister rajnath singh and mos home have met pm narendra modi and briefed him on the situation\n#earthquake\n"
# Text: "in pictures man is lucky to be rescued as massive earthquake hits nepal"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "ap at least killed in magnitude quake in nepal"
# Text: "nepal home ministry says at least people killed in the earthquake nepal home ministry says at least"
# Text: "earthquake helpline at the indian embassy in kathmandu"
# Text: "some pictures of earthquake in nepal #nepalearthquake"
# Text: "pls share spread the contact numbers for nepal helplines #earthquake #rt"
# Text: "breaking at least people killed in magnitude earthquake in nepal"
# Text: "ap avalanche sweeps everest in nepal injured"
# Text: "terrible scenes in nepal shows how fragile the world really is and how quickly life can be snatched away"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "avalanche sweeps everest in nepal injured kathmandu nepal ap senior mountaineering gui #slavetrade"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "breaking nepal #earthquake triggers #avalanche on north mt qomolangma everest altitude in china tibet climbers no casualty"
# Text: "live nepal cabinet meets to seek foreign help feared dead after massive quake via"
# Text: "at least killed in magnitude quake in nepal kathmandu nepal ap nepal home ministry says at leas"
# Text: "sending heartfelt prayers to those in #nepal and friends with family there unbelievable that nature can be so destructive"
# Text: "mt terrible #earthquake in #nepal just saved ourselves don know how many killed"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "praying for the safety of the beautiful people of nepal xxxxxx"
# Text: "tourists to nepal from maharashtra safe indian embassy helpline number in nepal"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "earthquake helpline at the indian embassy in kathmandu"
# Text: "#nepal after shock latest magnitude"
# Text: "#nepalearthquake \npm \nspoke with nepal prez pm\ncm bihar mp wb sikkim\nup mp sitamarhi\nbhutan emb\nhigh level meeting\nndrf dispatched\nwow"
# Text: "kathmandu historic dharahara tower collapses in nepal quake people reportedly trapped in rubble pic via"
# Text: "#prayforkathmandu rt terrible scenes of #kathmandu after large #earthquake strikes"
# Text: "quake magnitude upgraded to only km deep"
# Text: "earthquake in nepal devastating loss of life property seems enormous govt people of bharat will do everything to help our brethren"
# Text: "breaking killed in #earthquake in india including children epicenter in #nepal"
# Text: "#earthquake hit outside kathmandu #nepal crs #india is organizing teams to go there asap #nepalearthquake"
# Text: "in times as these from cyclones in odisha to floods in kashmir to earthquake in nepal swayamsevaks are ever ready to serve selflessly"
# Text: "hi com you shook this off? forreals?"
# Text: "ap at least killed in magnitude quake in nepal kathmandu nepal ap nepal home ministry says at"
# Text: "#google launches person finder service to help track people missing after #nepal #earthquake"
# Text: "following massive earthquake flights to kathmandu put on hold"
# Text: "taking break started #nepal quake list here will add more accts later"
# Text: "left #kathmandu in already infrastructure nightmare right after quake #nepal will struggle to recover"
# Text: "breaking news nepal ministry of home affairs says more than dead in kathmandu following earthquake"
# Text: "#ap at least killed in magnitude quake in nepal kathmandu nepal ap nepal home ministry says at"
# Text: "sir pls go all out in helping #nepal rescue and re construction of #nepal"
# Text: "warning india tremors felt from quake in #kathmandu to #kolkata amp #kochi too"
# Text: "at least killed in magnitude quake in nepal kathmandu nepal ap nepal home ministry #slavetrade"
# Text: "strong earthquake strikes nepal lt"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "at least reportedly killed as magnitude earthquake hits nepal"
# Text: "witness dust rises amid rubble in bhaktapur near kathmandu after major earthquake aftershocks continue"
# Text: "rss volunteers are leaving for nepal \n#earthquake"
# Text: "news latest pics sent to ani from kathmandu of #earthquake aftermath"
# Text: "list of doctors and hospitals in nepal"
# Text: "we ve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "ap tv dead injured in bangladesh from nepal quake"
# Text: "rss volunteers are leaving for nepal \n#earthquake"
# Text: "buildings collapse in nepal capital after quake\n\n"
# Text: "update humanitarian crisis in nepal dead toll may rises to prayers amp thought for nepalese friends"
# Text: "the bbc put the death toll even higher"
# Text: "may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"
# Text: "update humanitarian crisis in nepal dead toll may rises to prayers amp thought for nepalese friends"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "nepal home ministry says at least people killed in the earthquake nepal home ministry says at least people killed in the"
# Text: "dead in nepal earthquake dharahara tower collapses mt everest climbers missing"
# Text: "these are the emergency contact numbers for nepal please help spread amp share prayers for nepal #earthquake"
# Text: "breaking at least people killed in magnitude earthquake in nepal"
# Text: "next on the end draws near for the #bali traffickers scores killed in massive earthquake in nepal and wrap of #anzac"
# Text: "in times as these from cyclones in odisha to floods in kashmir to earthquake in nepal swayamsevaks are ever ready to serve selflessly"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from earthquake that originated"
# Text: "people gathered in open space in naxal kathmandu #nepalquake"
# Text: "earthquake km nnw of nagarkot nepal apr at epicenter ago depth km"
# Text: "no way to escape #earthquake kathmandu"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "latest pics sent to ani from kathmandu of #earthquake aftermath"
# Text: "three disasters in year for one of the poorest countries in the world the latest the deadliest #nepal #earthquake"
# Text: "#dharahara bhimsen tower the th century storey tall tower in #kathmandu has collapsed #nepalquake #nepal"
# Text: "tv dead injured in bangladesh from nepal quake dhaka bangladesh ap tv report says tha #spbnews"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "dad would have been in nepal today canceled his trip last min thanking god praying for the families that have been affected #earthquake"
# Text: "people of nepal india bangladesh thinking about you #earthquake"
# Text: "rt reports of avalanches on mt everest in the wake of the nepal earthquakes reports"
# Text: "aftershocks felt in span of hours since the massive magnitude earthquake in nepal"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+"
# Text: "nepal #earthquake latest \n\n reports of avalanches in everest\n temples flattened\n unknown numbers killed amp injured"
# Text: "earthquake helpline at the indian embassy in kathmandu"
# Text: "latest killed in magnitude #nepal earthquake local police"
# Text: "usgs has upgraded the strength of #nepal #earthquake to magnitude up from"
# Text: "we ve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "dozens injured as magnitude earthquake hits nepal capital kathmandu"
# Text: "mea opens hour control room for queries regarding the nepal earthquake \nnumbers \n+ \n+ \n+"
# Text: "death are confirmed by nepali government just in kathmandu #earthquake"
# Text: "kathmandu iconic dharahara tower destroyed for second time in earthquake"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "at least killed in magnitude quake in nepal from #apress #tns"
# Text: "avalanche sweeps everest in nepal injured kathmandu nepal ap senior mountaineering guide #spbnews"
# Text: "update humanitarian crisis in nepal dead toll may rises to prayers amp thought for nepalese friends"
# Text: "massive earthquake in nepal indian embassy helplines"
# Text: "#breaking more than killed in nepal earthquake says interior ministry"
# Text: "my heart goes out to each and every victim of the earthquakes in nepal and bihar let help and do whatever we can"
# Text: "earthquake in delhi and nepal omg \nmore than people died"
# Text: "#youdontsay at least killed in magnitude quake in nepal kathmandu nepal ap nepal home mini"
# Text: "rescuers clear the debris at durbar sqaure after an earthquake in kathmandu image ap"
# Text: "tv dead injured in bangladesh from nepal quake"
# Text: "thankyou for all the retweets sir once again guys here are the contact numbers for nepal share help"
# Text: "raw powerful earthquake rocks nepal #associatedpress #associated #press #news"
# Text: "avalanche sweeps everest in nepal injured"
# Text: "#earthquickinnepal shocing news earthquick in nepal may god all safe"
# Text: "oh my \n#nepal earthquake"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "have directed officials to take steps to restore communication lines in indo nepal border communications amp it minister ravi shankar prasad"
# Text: "prayers go out to all those affected by the earthquake #earthquake #nepal"
# Text: "more than people killed in powerful nepal earthquake say government officials and police"
# Text: "delhi cm resigned after taking moral responsibility for nepal #earthquake he also expelled ashutosh for thursday tantrums"
# Text: "dharahara also called bhimsen tower was nine storey tall tower at the center of sundhara kathmandu"
# Text: "slideshow of #nepal damage buildings collapsed rubble children injured significant humanitarian needs likely"
# Text: "at least killed in #nepal #earthquake according to home ministry afp reports"
# Text: "eu humaid monitoring situation in #kathmandu in contact with eu experts in the region partners"
# Text: "emergency helpline numbers pls rt and share #earthquake #nepal #nepalearthquake kathmandu"
# Text: "some friends in sydney who come from #nepal can reach their families my prayers are with them #nepalearthquake #nepalquake #earthquake"
# Text: "#youdontsay tv dead injured in bangladesh from nepal quake dhaka bangladesh ap tv report"
# Text: "earthquake in kathmandu nepal flights to kathmandu were diverted to indian airports\n as per cnn reporter in kathmandu dead bodies"
# Text: "weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "indian embassy helpline nepal +\nand other numbers #earthquake"
# Text: "an earthquake has killed at least people in nepal details are just starting to come in we ll have the latest"
# Text: "#youdontsay avalanche sweeps everest in nepal injured kathmandu nepal ap senior mountaineerin"
# Text: "nepal home ministry says at least people killed in the earthquake"
# Text: "devastating earthquake in nepal and north india"
# Text: "we ve just launched person finder instance to help track missing persons for the #nepal earthquake gt"
# Text: "avalanche sweeps everest in nepal injured from #apress #tns"
# Text: "child teenager killed in nepal earthquake"
# Text: "nepal earthquake nation hit by worst tremor in years live updates"
# Text: "cannot believe woke up to hear this terrible news about nepal hope and pray that everyone is safe back home #prayfornepal"
# Text: "police say at least people killed after the magnitude earthquake in nepal"
# Text: "tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"
# Text: "god this is nepal earthquake shot song here for mahaan with zeenat aman pray all well"
# Text: "it okay now sarah but we should pray for nepal bc they were hit the worst from this"
# Text: "pray for #nepal where powerful earthquake has struck may the almighty grant them ease to face this calamity with utmost strength aameen"
# Text: "#msghelpearthquakevictims shocked hearing earthquake in nepal some parts of india pray to god to save his children"
# Text: "big expresses shock over nepal quake reminisces mahaan shoot click here gt #larambhupathi"
# Text: "witness dust rises amid rubble in bhaktapur near kathmandu after major earthquake aftershocks continue"
# Text: "renowned shri pashupati nath temple complex in kathmandu has sufferred no damage is safe acc to reports"
# Text: "at the moment yes he is airport apparently opening soon and he doesn leave home till has had contact with agent in nepal"
# Text: "serious damage in nepal from quake indian states of sikkim and bihar also affected"
# Text: "#breakingnews at least killed in magnitude quake in nepal kathmandu nepal ap nepal home via"
# Text: "police say at least people killed after the magnitude earthquake in nepal"
# Text: "so sad to hear about the disaster in #nepal my prayers with the victims and their families my relatives cud feel tremors in #kolkata"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "earthquake hits nepal tremors felt in delhi and many other indian cities"
# Text: "say prayer for nepal images of earthquake wrought destruction are hauntingly familiar"
# Text: "strong earthquake strikes nepal"
# Text: "mea control room no for nepal #earthquake \n+ \n+"
# Text: "#breakingnews avalanche sweeps everest in nepal injured kathmandu nepal ap senior mountain via"
# Text: "news about nepal amp some parts of india being hit by #earthquake is saddening praying for strength to stand strong in such sudden calamities"
# Text: "earthquake in nepal north india the times of india"
# Text: "terrible earthquake in india and specially in nepal in kathmandu"
# Text: "magnitude earthquake rocks nepal leveling buildings causing an avalanche on mt everest"
# Text: "thankyou for all the retweets sir once again guys here are the contact numbers for nepal share help"
# Text: "police say at least people killed after the magnitude earthquake in nepal"
# Text: "indian embassy helpline nepal +\n\nand other numbers #earthquake"
# Text: "#breakingnews tv dead injured in bangladesh from nepal quake dhaka bangladesh ap tv re via"
# Text: "nepal earthquake even felt on the slopes of mt everest"
# Text: "my prayers are with people of nepal hope the earthquake does not leave too many casualties #earthquake"
# Text: "yahoonews more from ap nepal home ministry says at least people were killed in the earthquake"
# Text: "bodies counted in kathmandu civil hospital after #earthquake reuters reports"
# Text: "more than killed in powerful nepal #earthquake say government officials and police"
# Text: "avalanches reported in mount everest region after powerful earthquake in nepal"
# Text: "nepal earthquake in maps tweets and pictures"
# Text: "google has just launched person finder to help track missing persons #earthquake #nepal"
# Text: "this felt like very powerful earthquake reports of heavy damage in kathmandu hope up bihar villages are safe"
# Text: "breaking at least people killed in magnitude earthquake in nepal"
# Text: "emergency contact numbers for nepal kartikeyan siddharth sathyaraj"
# Text: "strong earthquake rocks nepal damages kathmandu #hb"
# Text: "how about you guys setting up nepal #earthquake relief fund? it chaos now you may fwd the money later to authentic players"
# Text: "at least people were injured in the avalanches that swept mt everest after the nepal earthquake reports"
# Text: "tv dead injured in bangladesh from nepal quake dhaka bangladesh ap tv report says that two peo"
# Text: "nepal #earthquake we have spoken to our team on the ground who are assessing the situation and humanitarian need more details to follow"
# Text: "pictures from kathmandu show damage of magnitude #earthquake reports of injuries"
# Text: "god this is nepal earthquake shot song here for mahaan with zeenat aman pray all well"
# Text: "nepal quake kathmandu airport shut flights from india cancelled toi mobile the times of india mobile site"
# ...
# Text: "please keep spreading message"
# Text: "prometheus doctors head out to #nepal with #ukisar"
# Text: "supplies are in gorkha but access to affected area almost impossible heilcopters cant go anywhere because of the bad weather"
# Text: "dont rush to nepal to help read this first claire bennett"
# Text: "so happy that your brother zachary has been found safe sheridan xx #nepal"
# Text: "use your donation wisely please support this #nepal #earthquake appeal"
# Text: "how to help #nepalquake victims?\n representative will take your queries pm only on cnn ibn\nask now"
# Text: "stretch helping hand to the people of #nepal through facebook"
# Text: "in #kathmandu walls buckle and buildings tilt at dangerous angles here cafe in an area packed with guesthouses"
# Text: "exclusive #nepal rebuilding cost to exceed billion finance chief says via"
# Text: "dont rush to nepal to help read this first\n"
# Text: "what type of religion is this who are trying to get advantage of this disaster when humanity is crying of pain"
# Text: "rt nepalese amp indian medical specialists in action at national trauma"
# Text: "if you have any concerns about the tragedy #nepalearthquake consult with amp for their updates amp helpful advice"
# Text: "#nepalearthquake jitendra singh arranges free insulin for diabetes patients\n"
# Text: "thanks received it we ve so far target within next few days pl promote it"
# Text: "this service has been very good to connect missing in nepal and their families or friends"
# Text: "create your own campaign"
# Text: "#helpnepal german nepalese friendship society collects donations no bureaucracy but existencial help"
# Text: "can sleep haunted by the future #baltimore #whatareyouafraidof #nepalearthquake #bestfandomca #apocalypse"
# Text: "#emergency in #nepal your #help needed\n\n"
# Text: "urgent appeal #nepalquakerelief please help anyway or much you can"
# Text: "death toll in #nepal may touch #koirala"
# Text: "rt eos what lessons do scientists hope to learn from the #nepalearthquake?"
# Text: "am proud of microsoft my company microsoft helping nepal citizens"
# Text: "note from nepal didnt expect to receive thisespecially from nepal #climatetracker #unfccc"
# Text: "#india #asks its citizens in nepal not to panic"
# Text: "hyatt of disregard #nepalquake"
# Text: "if not from uk check this link out people uk"
# Text: "stay strong nepal"
# Text: "prayers for nepal"
# Text: "posted photos on facebook in the album survivors working together in nepal"
# Text: "this is pathetic reporting india is doing more that nepal gov"
# Text: "*please see below an important message from nabin rijal fsu student from nepal and department of physics"
# Text: "#nepalearthquake additional train coaches added for relatives of quake victims"
# Text: "don rush to nepal to help read this first #nepalearthquake #nepalquake #nepalquakerelief"
# Text: "glad to see coverage of who doing what in #eu re #nepalearthquake #playbook"
# Text: "report of fapa and fapa foundation in action to aprial nepal eartquake\n"
# Text: "#unhcr sends solar powered lanterns to #nepal via #nepalquakerelief"
# Text: "where all the supplies going? people saying they not gettin anything nd say crores of supplies hav been sent #nepalearthquake"
# Text: "let update these numbers in our record"
# Text: "#indiawithnepal please extend ur help #uttishtabharatha"
# Text: "doctors in nepal appealing for more help"
# Text: "oxfam shop waterford taking donations money clothes #nepalearthquake"
# Text: "thank you #skype for all calls to and from nepal are free including calls to mobiles and land lines #nepal earthquake response"
# Text: "god help them"
# Text: "don be bystander be an upstander"
# Text: "please help support amp org respond nepal via our fund"
# Text: "go dogs"
# Text: "how about you sign new contract first"
# Text: "indian airforce arrived in #lukla today #indiawithnepal"
# Text: "nobody repeat nobody will talk bout this deeds of baba ramdev and vhp"
# Text: "all political parties in nepal are corrupted have not seen any of the leaders in action as layman"
# Text: "david missing since #nepalearthquake please rt"
# Text: "rescue crews reach stranded hikers in nepal langtang region world"
# Text: "david missing since #nepalearthquake please rt"
# Text: "please give aid to an accredited aid agency #itcouldbeus"
# Text: "\n\ndonating please everyone do it"
# Text: "#mobilenews how tech companies are helping nepal earthquake relief efforts"
# Text: "another reason hate people my age and their love of selfies"
# Text: "doctors in nepal appealing for more help"
# Text: "this is so heartbreaking wtf"
# Text: "#nepalquake the death toll has risen to around according to local officials expected to rise significantly"
# Text: "#cle flower clown brings smiles to children of nepal an incredible ambassador of smiles"
# Text: "nepal quake additional train coaches for relatives of victims #elections #achedin #politics"
# Text: "four families living out of the same tent after the #nepalearthquake help"
# Text: "contribute to the nepal earthquake relief effort"
# Text: "one more update from my husband uncle in #thame #nepal np"
# Text: "villagers are evacuated in an indian army helicopter from remote villages devastated by the #nepalearthquake"
# Text: "david missing since #nepalearthquake please rt"
# Text: "vhp offers to rebuild temples damaged in #nepalquake"
# Text: "terrified nepal patients want treatment in tents not in hospital buildings"
# Text: "my dear friends good luck go and save some lives"
# Text: "oh no"
# Text: "#earthquake in #nepal view from an indian army helicopter in the hills of #gorkha via #afp"
# Text: "there is fb page to share your news photos requests and videos about sankhu at please like and share"
# Text: "david missing since #nepalearthquake please rt"
# Text: "asta partners with tourism cares on nepal recovery"
# Text: "happy #charitytuesday everyone please support xx"
# Text: "#nepalearthquake ensures that people have access to information in languages they understand #commisaid"
# Text: "there is fb page to share your news photos requests and videos about sankhu at please like and share"
# Text: "it was like trying to walk on fast rowing boat #wfp staff member describes the #nepalquake"
# Text: "dont rush to nepal to help read this first claire bennett"
# Text: "reminder will meet with delegates who will be departing for #nepal at et"
# Text: "doctors in nepal appealing for more help cnn dr sanjay gupta reports that hospitals in"
# Text: "hill is cracking there might be landslide #nepalearthquake #lukla #help"
# Text: "hoping they can be found ezra"
# Text: "came here last eve took us hrs to set up makeshift hospital rk yadav commanding officer amc #nepalearthquake"
# Text: "live angry nepalis dig rubble themselves pm sushil koirala says toll could reach"
# Text: "am fund raising for nepal earthquake please donate as much as you can many thanks"
# Text: "up to missing in nepal"
# Text: "rt pls help if you can isar team"
# Text: "what the media won tell you"
# Text: "miraculously no one seriously hurt here by #nepalquake on left can see sheets people used to escape damaged house"
# Text: "indian army\nwe have completed establishment of bedded hospital at lagankhel nepal \n#saluteindianarmy"
# Text: "please let others know about any that you may be working on #nepalearthquake #survey"
# Text: "vishwa guru global leader \n#usa except #nepalearthquake \n#saluteindianforces \n#thankyoupm"
# Text: "cook after and donation it apple time to show social responsibility to nepal #nepalearthquake #nepalqakerelief"
# Text: "that what the friendship is\n"
# Text: "reliable fund trust share amp donate #nepal fund prabal gurung amp shikshya foundation"
# Text: "david missing since #nepalearthquake please rt"
# Text: "posted photos on facebook in the album #nepalquake destruction in core city area"
# Text: "due to the devastation in #nepal selling this print for just with all proceeds going to help"
# Text: "you don need money to help out via"
# Text: "five videos that captured the #nepalearthquake aftershocks and damage"
# Text: "stop your action nepali people living abroad please do not post save nepal help nepal if you really care then"
# Text: "david missing since #nepalearthquake please rt"
# Text: "if we can take lessons from nepal the results in india would be devastating be ready for that or start doing resistant construction"
# Text: "great news collection at clyro school today for anyone else with donations leaving for london tomorrow am #nepalearthquake"
# Text: "#nepalearthquake additional train coaches added for relatives of quake victims"
# Text: "dont rush to #nepal to help read this first claire bennett"
# Text: "#operationmaitri continues as feel proud that #saluteindianforces for their work at #nepalearthquake for our blood"
# Text: "am supporting rebuild sankhu #crowdfunder"
# Text: "hope you guys have reached sindhupalchowk good luck #nepalrelief #nepalquake"
# Text: "help nepal villages #crowdfunding support and retweet #helpnepal #charity"
# Text: "plastics in rescue mission"
# Text: "prayers to all those touched by this"
# Text: "prime minister of nepal says death toll could reach"
# Text: "another plane is scheduled to leave today we ve also sent army teams for medical assistance neeraj musalay #nepalearthquake"
# Text: "heart breaking photographs scenes from #nepalearthquake"
# Text: "nepal tragedy devastating loss of human life and ancient heritage"
# Text: "dis is legitimate charity dat we donate right now collecting nepal pls rt morning"
# Text: "not only are the indian armed forces doing almost everything in india now they do everything around too?"
# Text: "poor jill and derick sure #nepalearthquake is affecting them personally #kids"
# Text: "if you re thinking of making donation for #nepalquake you should consider using the website all donations are doubled"
# Text: "it is pathetic though that on had to scroll through odd bali stories to find any on nepal"
# Text: "update airlifting from rimche guest house area dhwani dalal amp rest others today #nepalearthquake"
# Text: "continued prayers for the people affected by the #nepalquake and the for the emergency response teams"
# Text: "welcome to helping hands nepal"
# Text: "is doing something in #earthquake #nepal or not"
# Text: "jblm green berets in nepal for military exercise now treating earthquakes injured"
# Text: "say prayer for #boston and #nepalearthquake victims"
# Text: "fitz check out how we are donating to over twitter via \npretty rad #nepalearthquake"
# Text: "me sum frnds wanna make bulk donations of value for #nepalearthquake can help contact sum frm #timescares project"
# Text: "kunal kohli india helping nepal is instinctive to us as people govt amp armed for"
# Text: "it doesn matter how much just give #nepalearthquake #keephopealive"
# Text: "it so disrespectful that nepal is in in other news #nepal"
# Text: "landslide following #nepalearthquake has left at least people missing officials say"
# Text: "how wish could go to nepal to tk care of suffering children look at these appeals by vhp rss"
# Text: "office of the resident coordinator\nsituation report no as of april pm \n#nepalquake"
# Text: "pick unicef and umcor"
# Text: "the way you jurno say teens it gives an impression of they are bloody adults via"
# Text: "thank you all for tweeting see some big names who ve been talking about #nepalearthquake gt"
# Text: "world bank group offers help to nepal world bankgroup"
# Text: "the whole wall would have collapsed on me and would have died stories of survivors of the #nepalearthquake http"
# Text: "and many of us will have to think twice about giving to the nepal disaster or easier not to think about it at all leave it to floyd"
# Text: "trail of destruction across himalayan kingdom as hospitals are overwhelmed by injured nepal deadly earthquake"
# Text: "update some help in sindhupalchowk but #nepalrelief not yet in kavre? kids at risk pls help them #nepalearthquake"
# Text: "eindhoven weather nepal faces larger and more deadly earthquakes even after the magnitude temblor that"
# Text: "any donation is welcomed but hav ellen announce it on her show is heartfelt hugs india thank fr remembering nepal"
# Text: "kim yuna shows her concern with charitable donation of to nepal via holy yuna"
# Text: "fyi anyhow re temporary #coordination intl sar teams in the capital \n\n#nepalquake"
# Text: "donated #nepalearthquake it how much we give bt how much love we put into giving \n#nepalearthquakerelieffund"
# Text: "instagram by yuvalcohenitis great feeling to bring tons of humanitarian aids to nepal katmandu"
# Text: "tourist couple was filming kathmandu durbar sq from the th floor when the quake hitbirds flee amid screamshttp #nepal"
# Text: "help them by donating"
# Text: "support unicef connect and share gt gt #nepal #donate #dona #urge"
# Text: "unbelievable support from india nepal ambassador"
# Text: "be careful when donating to nepal lots of low life scammers out there"
# Text: "#nepalquake it another after shock in th day in the morning too scary"
# Text: "indian army team pulls out bodies after #everest avalanche neighbours news #zippednews"
# Text: "god bless israel"
# Text: "so glad you made it safely let me know how can help keep up the great work amp be the voice for us back home #nepal"
# Text: "portable water filters headed to #kathmandu me weds enough to supply people thank you"
# Text: "fedex is not offering free service in nepal but helping in other ways"
# Text: "we re finally in nepal and assessing gorkha"
# Text: "please rt just released new single not shit for #nepalearthquake thanks media dudes"
# Text: "great reporting by for on the status of #nepal key historic sites"
# Text: "heart touching pictures #earthquake #nepal #praynepal #minnalfm"
# Text: "nd #nepal quake hit fieldbase but thankfully katmandu staff safe follow for updates from the ground"
# Text: "#afp journalists recall the moment when #mounteverest came tumbling down #nepal #quake"
# Text: "dear malaysian government there are malaysians stranded in lukla most can make their way to kathmandu and situation is getting worse"
# Text: "by yuvalcohenitis great feeling to bring tons of humanitarian aids to nepal katmandu"
# Text: "priorities are on my mind facebook"
# Text: "to quote some on fb it speaks volumes about nepal and its people that so many of its visitors feel personally touched by this tragedy"
# Text: "during typhoon #yolandaph you helped by selling signed abs jersey cause please do the same nepal #deadstillcounting"
# Text: "local nepalese community raises money for nepal earthquake victims"
# Text: "ask the oz gov mill to nepal $mill to build war structure france before next anzac day ??"
# Text: "mourning the devastation in nepal and call to action"
# Text: "we did our best to give her first aid but unfortunately we couldnt save her heartbreaking stories"
# Text: "thanks everyone for your lovely tweets apologies for not replying internet access is very limited #nepal #news"
# Text: "ca tf urban search and rescue and fd are on the ground in #nepal"
# Text: "god help them and send help to them asap~"
# Text: "yuna kim donates to nepal earthquakerelief via"
# Text: "doctors without borders are sending teams supplies from delhi france brussels amp amsterdam to nepal help them"
# Text: "nepal direct help to in need help here via shechen monastery"
# Text: "please retweet amp donate to #savethechildren help #nepal now"
# Text: "bless them"
# Text: "help the victims of the #nepalearthquake"
# Text: "useful ewf guidance notes on nepal landslides"
# Text: "never ending love of husband amp wife snap of couple died in #nepalearthquake"
# Text: "today tarpaulins assistance of pmi will depart at wib to nepal #nepalearthquake"
# Text: "growing humanitarian crisis in nepal many countries asking its citizens not to go there yet aa not offering cancellation?"
# Text: "thank you for being with all the time love you"
# Text: "foto andreitintea pikxchu nepal trekking the annapurna circuit bykelsey austin walsh follow this blog"
# Text: "please share this nepal needs us #nepalquakerelief"
# Text: "these planes are talking so much things my goverment cant you distribute properly #nepal #earthquick"

# %%
spark.read.option("header","true").csv("data/nepal_pos_tot.csv")
# Out:
# DataFrame[tweet_id: string, tweet_text: string, label: string]

# %% [markdown]
# ## Tokenise

# %%
from pyspark.ml.feature import Tokenizer, RegexTokenizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType

tokenizer = Tokenizer(inputCol="tweet_text", outputCol="words")
regexTokenizer = RegexTokenizer(inputCol="tweet_text", outputCol="words", pattern="\\W")
# alternatively, pattern="\\w+", gaps(False)

countTokens = udf(lambda words: len(words), IntegerType())

tokenized = tokenizer.transform(positive_tweets)
tokenized.select("tweet_text", "words")\
    .withColumn("tokens", countTokens(col("words"))).show(truncate=False)
    
regexTokenized = regexTokenizer.transform(positive_tweets)
regexTokenized.select("tweet_text", "words") \
    .withColumn("tokens", countTokens(col("words"))).show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |tweet_text                                                                                                                                |words                                                                                                                                                           |tokens|
# +------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |"#indiawithnepal my thoughts with those affected in nepal quake very strong tremors in padrauna kushinagar too we re just bordering nepal"|["#indiawithnepal, my, thoughts, with, those, affected, in, nepal, quake, very, strong, tremors, in, padrauna, kushinagar, too, we, re, just, bordering, nepal"]|21    |
# |"nepal earthquake in maps tweets and pictures"                                                                                            |["nepal, earthquake, in, maps, tweets, and, pictures"]                                                                                                          |7     |
# |"#news nepal home ministry says at least people killed in the earthquake nepal home ministry says #tu"                                    |["#news, nepal, home, ministry, says, at, least, people, killed, in, the, earthquake, nepal, home, ministry, says, #tu"]                                        |17    |
# |"#earthquake helpline numbers of the indian embassy in nepal \n+ \n\n+"                                                                   |["#earthquake, helpline, numbers, of, the, indian, embassy, in, nepal, \n+, \n\n+"]                                                                             |11    |
# |"more than killed in powerful nepal #earthquake say government officials and police"                                                      |["more, than, killed, in, powerful, nepal, #earthquake, say, government, officials, and, police"]                                                               |12    |
# |"#earthquakeinnepal\nhelpline numbers of indian embassy in kathmandu \n\n \n\nplease help by re tweeting"                                 |["#earthquakeinnepal\nhelpline, numbers, of, indian, embassy, in, kathmandu, \n\n, \n\nplease, help, by, re, tweeting"]                                         |13    |
# |"divastating earthquake shakes the soul of the people #nepal"                                                                             |["divastating, earthquake, shakes, the, soul, of, the, people, #nepal"]                                                                                         |9     |
# |"#news tv dead injured in bangladesh from nepal quake tv report dead injured in banglades #tu"                                            |["#news, tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, banglades, #tu"]                                                 |16    |
# |"pictures from kathmandu show damage of magnitude #earthquake"                                                                            |["pictures, from, kathmandu, show, damage, of, magnitude, #earthquake"]                                                                                         |8     |
# |"tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"                                           |["tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, bangladesh, from, eart"]                                                |16    |
# |"#breaking at least killed in nepal earthquake home ministry"                                                                             |["#breaking, at, least, killed, in, nepal, earthquake, home, ministry"]                                                                                         |9     |
# |"magnitude quake hits nepal causing big damage injuries the damage includes toppled walls and collapsed"                                  |["magnitude, quake, hits, nepal, causing, big, damage, injuries, the, damage, includes, toppled, walls, and, collapsed"]                                        |15    |
# |"earthquake km nne of nagarkot nepal apr at epicenter ago depth km"                                                                       |["earthquake, km, nne, of, nagarkot, nepal, apr, at, epicenter, ago, depth, km"]                                                                                |12    |
# |"witness nepal quake was massive kathmandu is crumbling"                                                                                  |["witness, nepal, quake, was, massive, kathmandu, is, crumbling"]                                                                                               |8     |
# |"people finder live quake map emergency numbers #nepal"                                                                                   |["people, finder, live, quake, map, emergency, numbers, #nepal"]                                                                                                |8     |
# |"tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"                                           |["tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, bangladesh, from, eart"]                                                |16    |
# |"weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"                                    |["weve, just, launched, person, finder, instance, to, help, track, missing, persons, for, the, #nepal, earthquake, gt"]                                         |16    |
# |"indian air force is ready to help the people of nepal #salutetoarmy\n\n#earthquake #indiawithnepal"                                      |["indian, air, force, is, ready, to, help, the, people, of, nepal, #salutetoarmy\n\n#earthquake, #indiawithnepal"]                                              |13    |
# |"may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"                              |["may, allah, look, after, all, here, the, emergency, contact, numbers, for, nepal, share, help, prayers, with, all, in, nepal"]                                |19    |
# |"it is also climbing season and there are many sherpa villages near everest over avalanches being reported #nepal #nepalearthquake"       |["it, is, also, climbing, season, and, there, are, many, sherpa, villages, near, everest, over, avalanches, being, reported, #nepal, #nepalearthquake"]         |19    |
# +------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# only showing top 20 rows
#
# +------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |tweet_text                                                                                                                                |words                                                                                                                                                        |tokens|
# +------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |"#indiawithnepal my thoughts with those affected in nepal quake very strong tremors in padrauna kushinagar too we re just bordering nepal"|[indiawithnepal, my, thoughts, with, those, affected, in, nepal, quake, very, strong, tremors, in, padrauna, kushinagar, too, we, re, just, bordering, nepal]|21    |
# |"nepal earthquake in maps tweets and pictures"                                                                                            |[nepal, earthquake, in, maps, tweets, and, pictures]                                                                                                         |7     |
# |"#news nepal home ministry says at least people killed in the earthquake nepal home ministry says #tu"                                    |[news, nepal, home, ministry, says, at, least, people, killed, in, the, earthquake, nepal, home, ministry, says, tu]                                         |17    |
# |"#earthquake helpline numbers of the indian embassy in nepal \n+ \n\n+"                                                                   |[earthquake, helpline, numbers, of, the, indian, embassy, in, nepal, n, n, n]                                                                                |12    |
# |"more than killed in powerful nepal #earthquake say government officials and police"                                                      |[more, than, killed, in, powerful, nepal, earthquake, say, government, officials, and, police]                                                               |12    |
# |"#earthquakeinnepal\nhelpline numbers of indian embassy in kathmandu \n\n \n\nplease help by re tweeting"                                 |[earthquakeinnepal, nhelpline, numbers, of, indian, embassy, in, kathmandu, n, n, n, nplease, help, by, re, tweeting]                                        |16    |
# |"divastating earthquake shakes the soul of the people #nepal"                                                                             |[divastating, earthquake, shakes, the, soul, of, the, people, nepal]                                                                                         |9     |
# |"#news tv dead injured in bangladesh from nepal quake tv report dead injured in banglades #tu"                                            |[news, tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, banglades, tu]                                                  |16    |
# |"pictures from kathmandu show damage of magnitude #earthquake"                                                                            |[pictures, from, kathmandu, show, damage, of, magnitude, earthquake]                                                                                         |8     |
# |"tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"                                           |[tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, bangladesh, from, eart]                                               |16    |
# |"#breaking at least killed in nepal earthquake home ministry"                                                                             |[breaking, at, least, killed, in, nepal, earthquake, home, ministry]                                                                                         |9     |
# |"magnitude quake hits nepal causing big damage injuries the damage includes toppled walls and collapsed"                                  |[magnitude, quake, hits, nepal, causing, big, damage, injuries, the, damage, includes, toppled, walls, and, collapsed]                                       |15    |
# |"earthquake km nne of nagarkot nepal apr at epicenter ago depth km"                                                                       |[earthquake, km, nne, of, nagarkot, nepal, apr, at, epicenter, ago, depth, km]                                                                               |12    |
# |"witness nepal quake was massive kathmandu is crumbling"                                                                                  |[witness, nepal, quake, was, massive, kathmandu, is, crumbling]                                                                                              |8     |
# |"people finder live quake map emergency numbers #nepal"                                                                                   |[people, finder, live, quake, map, emergency, numbers, nepal]                                                                                                |8     |
# |"tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"                                           |[tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, bangladesh, from, eart]                                               |16    |
# |"weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"                                    |[weve, just, launched, person, finder, instance, to, help, track, missing, persons, for, the, nepal, earthquake, gt]                                         |16    |
# |"indian air force is ready to help the people of nepal #salutetoarmy\n\n#earthquake #indiawithnepal"                                      |[indian, air, force, is, ready, to, help, the, people, of, nepal, salutetoarmy, n, n, earthquake, indiawithnepal]                                            |16    |
# |"may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"                              |[may, allah, look, after, all, here, the, emergency, contact, numbers, for, nepal, share, help, prayers, with, all, in, nepal]                               |19    |
# |"it is also climbing season and there are many sherpa villages near everest over avalanches being reported #nepal #nepalearthquake"       |[it, is, also, climbing, season, and, there, are, many, sherpa, villages, near, everest, over, avalanches, being, reported, nepal, nepalearthquake]          |19    |
# +------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# only showing top 20 rows

# %% [markdown]
# ## Stop words remover

# %%
from pyspark.ml.feature import StopWordsRemover

remover = StopWordsRemover(inputCol="words", outputCol="filtered")
remover.transform(tokenized).show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+
# |tweet_text                                                                                                                                |words                                                                                                                                                           |filtered                                                                                                             |
# +------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+
# |"#indiawithnepal my thoughts with those affected in nepal quake very strong tremors in padrauna kushinagar too we re just bordering nepal"|["#indiawithnepal, my, thoughts, with, those, affected, in, nepal, quake, very, strong, tremors, in, padrauna, kushinagar, too, we, re, just, bordering, nepal"]|["#indiawithnepal, thoughts, affected, nepal, quake, strong, tremors, padrauna, kushinagar, bordering, nepal"]       |
# |"nepal earthquake in maps tweets and pictures"                                                                                            |["nepal, earthquake, in, maps, tweets, and, pictures"]                                                                                                          |["nepal, earthquake, maps, tweets, pictures"]                                                                        |
# |"#news nepal home ministry says at least people killed in the earthquake nepal home ministry says #tu"                                    |["#news, nepal, home, ministry, says, at, least, people, killed, in, the, earthquake, nepal, home, ministry, says, #tu"]                                        |["#news, nepal, home, ministry, says, least, people, killed, earthquake, nepal, home, ministry, says, #tu"]          |
# |"#earthquake helpline numbers of the indian embassy in nepal \n+ \n\n+"                                                                   |["#earthquake, helpline, numbers, of, the, indian, embassy, in, nepal, \n+, \n\n+"]                                                                             |["#earthquake, helpline, numbers, indian, embassy, nepal, \n+, \n\n+"]                                               |
# |"more than killed in powerful nepal #earthquake say government officials and police"                                                      |["more, than, killed, in, powerful, nepal, #earthquake, say, government, officials, and, police"]                                                               |["more, killed, powerful, nepal, #earthquake, say, government, officials, police"]                                   |
# |"#earthquakeinnepal\nhelpline numbers of indian embassy in kathmandu \n\n \n\nplease help by re tweeting"                                 |["#earthquakeinnepal\nhelpline, numbers, of, indian, embassy, in, kathmandu, \n\n, \n\nplease, help, by, re, tweeting"]                                         |["#earthquakeinnepal\nhelpline, numbers, indian, embassy, kathmandu, \n\n, \n\nplease, help, tweeting"]              |
# |"divastating earthquake shakes the soul of the people #nepal"                                                                             |["divastating, earthquake, shakes, the, soul, of, the, people, #nepal"]                                                                                         |["divastating, earthquake, shakes, soul, people, #nepal"]                                                            |
# |"#news tv dead injured in bangladesh from nepal quake tv report dead injured in banglades #tu"                                            |["#news, tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, banglades, #tu"]                                                 |["#news, tv, dead, injured, bangladesh, nepal, quake, tv, report, dead, injured, banglades, #tu"]                    |
# |"pictures from kathmandu show damage of magnitude #earthquake"                                                                            |["pictures, from, kathmandu, show, damage, of, magnitude, #earthquake"]                                                                                         |["pictures, kathmandu, show, damage, magnitude, #earthquake"]                                                        |
# |"tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"                                           |["tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, bangladesh, from, eart"]                                                |["tv, dead, injured, bangladesh, nepal, quake, tv, report, dead, injured, bangladesh, eart"]                         |
# |"#breaking at least killed in nepal earthquake home ministry"                                                                             |["#breaking, at, least, killed, in, nepal, earthquake, home, ministry"]                                                                                         |["#breaking, least, killed, nepal, earthquake, home, ministry"]                                                      |
# |"magnitude quake hits nepal causing big damage injuries the damage includes toppled walls and collapsed"                                  |["magnitude, quake, hits, nepal, causing, big, damage, injuries, the, damage, includes, toppled, walls, and, collapsed"]                                        |["magnitude, quake, hits, nepal, causing, big, damage, injuries, damage, includes, toppled, walls, collapsed"]       |
# |"earthquake km nne of nagarkot nepal apr at epicenter ago depth km"                                                                       |["earthquake, km, nne, of, nagarkot, nepal, apr, at, epicenter, ago, depth, km"]                                                                                |["earthquake, km, nne, nagarkot, nepal, apr, epicenter, ago, depth, km"]                                             |
# |"witness nepal quake was massive kathmandu is crumbling"                                                                                  |["witness, nepal, quake, was, massive, kathmandu, is, crumbling"]                                                                                               |["witness, nepal, quake, massive, kathmandu, crumbling"]                                                             |
# |"people finder live quake map emergency numbers #nepal"                                                                                   |["people, finder, live, quake, map, emergency, numbers, #nepal"]                                                                                                |["people, finder, live, quake, map, emergency, numbers, #nepal"]                                                     |
# |"tv dead injured in bangladesh from nepal quake tv report dead injured in bangladesh from eart"                                           |["tv, dead, injured, in, bangladesh, from, nepal, quake, tv, report, dead, injured, in, bangladesh, from, eart"]                                                |["tv, dead, injured, bangladesh, nepal, quake, tv, report, dead, injured, bangladesh, eart"]                         |
# |"weve just launched person finder instance to help track missing persons for the #nepal earthquake gt"                                    |["weve, just, launched, person, finder, instance, to, help, track, missing, persons, for, the, #nepal, earthquake, gt"]                                         |["weve, launched, person, finder, instance, help, track, missing, persons, #nepal, earthquake, gt"]                  |
# |"indian air force is ready to help the people of nepal #salutetoarmy\n\n#earthquake #indiawithnepal"                                      |["indian, air, force, is, ready, to, help, the, people, of, nepal, #salutetoarmy\n\n#earthquake, #indiawithnepal"]                                              |["indian, air, force, ready, help, people, nepal, #salutetoarmy\n\n#earthquake, #indiawithnepal"]                    |
# |"may allah look after all here the emergency contact numbers for nepal share help prayers with all in nepal"                              |["may, allah, look, after, all, here, the, emergency, contact, numbers, for, nepal, share, help, prayers, with, all, in, nepal"]                                |["may, allah, look, emergency, contact, numbers, nepal, share, help, prayers, nepal"]                                |
# |"it is also climbing season and there are many sherpa villages near everest over avalanches being reported #nepal #nepalearthquake"       |["it, is, also, climbing, season, and, there, are, many, sherpa, villages, near, everest, over, avalanches, being, reported, #nepal, #nepalearthquake"]         |["it, also, climbing, season, many, sherpa, villages, near, everest, avalanches, reported, #nepal, #nepalearthquake"]|
# +------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## NGram

# %%
from pyspark.ml.feature import NGram

ngram = NGram(n=3, inputCol="words", outputCol="ngrams")

ngramDataFrame = ngram.transform(tokenized)
ngramDataFrame.select("ngrams").show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |ngrams                                                                                                                                                                                                                                                                                                                                                                                 |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |["#indiawithnepal my thoughts, my thoughts with, thoughts with those, with those affected, those affected in, affected in nepal, in nepal quake, nepal quake very, quake very strong, very strong tremors, strong tremors in, tremors in padrauna, in padrauna kushinagar, padrauna kushinagar too, kushinagar too we, too we re, we re just, re just bordering, just bordering nepal"]|
# |["nepal earthquake in, earthquake in maps, in maps tweets, maps tweets and, tweets and pictures"]                                                                                                                                                                                                                                                                                      |
# |["#news nepal home, nepal home ministry, home ministry says, ministry says at, says at least, at least people, least people killed, people killed in, killed in the, in the earthquake, the earthquake nepal, earthquake nepal home, nepal home ministry, home ministry says, ministry says #tu"]                                                                                      |
# |["#earthquake helpline numbers, helpline numbers of, numbers of the, of the indian, the indian embassy, indian embassy in, embassy in nepal, in nepal \n+, nepal \n+ \n\n+"]                                                                                                                                                                                                           |
# |["more than killed, than killed in, killed in powerful, in powerful nepal, powerful nepal #earthquake, nepal #earthquake say, #earthquake say government, say government officials, government officials and, officials and police"]                                                                                                                                                   |
# |["#earthquakeinnepal\nhelpline numbers of, numbers of indian, of indian embassy, indian embassy in, embassy in kathmandu, in kathmandu \n\n, kathmandu \n\n \n\nplease, \n\n \n\nplease help, \n\nplease help by, help by re, by re tweeting"]                                                                                                                                         |
# |["divastating earthquake shakes, earthquake shakes the, shakes the soul, the soul of, soul of the, of the people, the people #nepal"]                                                                                                                                                                                                                                                  |
# |["#news tv dead, tv dead injured, dead injured in, injured in bangladesh, in bangladesh from, bangladesh from nepal, from nepal quake, nepal quake tv, quake tv report, tv report dead, report dead injured, dead injured in, injured in banglades, in banglades #tu"]                                                                                                                 |
# |["pictures from kathmandu, from kathmandu show, kathmandu show damage, show damage of, damage of magnitude, of magnitude #earthquake"]                                                                                                                                                                                                                                                 |
# |["tv dead injured, dead injured in, injured in bangladesh, in bangladesh from, bangladesh from nepal, from nepal quake, nepal quake tv, quake tv report, tv report dead, report dead injured, dead injured in, injured in bangladesh, in bangladesh from, bangladesh from eart"]                                                                                                       |
# |["#breaking at least, at least killed, least killed in, killed in nepal, in nepal earthquake, nepal earthquake home, earthquake home ministry"]                                                                                                                                                                                                                                        |
# |["magnitude quake hits, quake hits nepal, hits nepal causing, nepal causing big, causing big damage, big damage injuries, damage injuries the, injuries the damage, the damage includes, damage includes toppled, includes toppled walls, toppled walls and, walls and collapsed"]                                                                                                     |
# |["earthquake km nne, km nne of, nne of nagarkot, of nagarkot nepal, nagarkot nepal apr, nepal apr at, apr at epicenter, at epicenter ago, epicenter ago depth, ago depth km"]                                                                                                                                                                                                          |
# |["witness nepal quake, nepal quake was, quake was massive, was massive kathmandu, massive kathmandu is, kathmandu is crumbling"]                                                                                                                                                                                                                                                       |
# |["people finder live, finder live quake, live quake map, quake map emergency, map emergency numbers, emergency numbers #nepal"]                                                                                                                                                                                                                                                        |
# |["tv dead injured, dead injured in, injured in bangladesh, in bangladesh from, bangladesh from nepal, from nepal quake, nepal quake tv, quake tv report, tv report dead, report dead injured, dead injured in, injured in bangladesh, in bangladesh from, bangladesh from eart"]                                                                                                       |
# |["weve just launched, just launched person, launched person finder, person finder instance, finder instance to, instance to help, to help track, help track missing, track missing persons, missing persons for, persons for the, for the #nepal, the #nepal earthquake, #nepal earthquake gt"]                                                                                        |
# |["indian air force, air force is, force is ready, is ready to, ready to help, to help the, help the people, the people of, people of nepal, of nepal #salutetoarmy\n\n#earthquake, nepal #salutetoarmy\n\n#earthquake #indiawithnepal"]                                                                                                                                                |
# |["may allah look, allah look after, look after all, after all here, all here the, here the emergency, the emergency contact, emergency contact numbers, contact numbers for, numbers for nepal, for nepal share, nepal share help, share help prayers, help prayers with, prayers with all, with all in, all in nepal"]                                                                |
# |["it is also, is also climbing, also climbing season, climbing season and, season and there, and there are, there are many, are many sherpa, many sherpa villages, sherpa villages near, villages near everest, near everest over, everest over avalanches, over avalanches being, avalanches being reported, being reported #nepal, reported #nepal #nepalearthquake"]                |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## HashingTF and IDF

# %%
from pyspark.ml.feature import HashingTF, IDF, Tokenizer

hashingTF = HashingTF(inputCol="words", outputCol="rawFeatures", numFeatures=20)
featurizedData = hashingTF.transform(tokenized)
# alternatively, CountVectorizer can also be used to get term frequency vectors

idf = IDF(inputCol="rawFeatures", outputCol="features")
idfModel = idf.fit(featurizedData)
rescaledData = idfModel.transform(featurizedData)

rescaledData.select("tweet_text", "features").show()
# Out:
# +--------------------+--------------------+
# |          tweet_text|            features|
# +--------------------+--------------------+
# |"#indiawithnepal ...|(20,[0,4,5,7,8,10...|
# |"nepal earthquake...|(20,[0,5,9,13,16]...|
# |"#news nepal home...|(20,[5,6,8,10,16,...|
# |"#earthquake help...|(20,[2,3,5,7,8,9,...|
# |"more than killed...|(20,[0,1,5,8,10,1...|
# |"#earthquakeinnep...|(20,[0,2,3,5,7,9,...|
# |"divastating eart...|(20,[2,3,6,9,10,1...|
# |"#news tv dead in...|(20,[1,5,6,8,10,1...|
# |"pictures from ka...|(20,[0,1,3,15,18,...|
# |"tv dead injured ...|(20,[1,5,8,9,10,1...|
# |"#breaking at lea...|(20,[5,8,13,16,17...|
# |"magnitude quake ...|(20,[1,3,7,8,9,10...|
# |"earthquake km nn...|(20,[1,3,6,8,9,12...|
# |"witness nepal qu...|(20,[0,1,7,8,9,10...|
# |"people finder li...|(20,[2,7,9,10,13,...|
# |"tv dead injured ...|(20,[1,5,8,9,10,1...|
# |"weve just launch...|(20,[2,5,7,8,9,10...|
# |"indian air force...|(20,[1,3,4,6,7,8,...|
# |"may allah look a...|(20,[5,7,8,9,10,1...|
# |"it is also climb...|(20,[1,5,6,8,9,10...|
# +--------------------+--------------------+
# only showing top 20 rows
